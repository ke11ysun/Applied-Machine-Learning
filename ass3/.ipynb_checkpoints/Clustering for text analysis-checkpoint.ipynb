# %% [markdown]
# ### Load data (doc-word)

# %%
import numpy as np
doc_word = np.load("science2k-doc-word.npy")
print(doc_word.shape)
print(doc_word[0])
# Out:
# (1373, 5476)
# [-0.2521619 -0.2521619  9.36371   ... -0.2521619 -0.2521619 -0.2521619]

# %%
# lol i though we were to calculate the features lol
# per-document smoothed word frequencies
f = []
for doc in doc_word:
    term_count = np.count_nonzero(doc)
    word_count = sum(doc)
    f_per_doc = []
    for word in doc:
        frequency = (word + 1)/(word_count + term_count)
        f_per_doc.append(frequency)
    f.append(f_per_doc)
f = np.asarray(f)
print(f.shape)
print(f[0])

# log frequencies
log_f = np.log(f)
print(log_f[0])
# Out:
# (1373, 5476)
# [0.00013657 0.00013657 0.00189257 ... 0.00013657 0.00013657 0.00013657]

# %% [markdown]
# ### K-means on doc-word

# %%
from sklearn.cluster import KMeans
k = 20
kmeans = KMeans(n_clusters=k, random_state=0).fit(doc_word)

# %%
# construct feature and corresponding label list

f = []
f_idx = []
for i in range(k):
    indices = np.where(kmeans.labels_ == i)
    f_idx.append(list(indices[0]))
    feature = np.zeros(doc_word.shape[1])
    for idx in indices:
        feature = np.vstack((feature, doc_word[idx]))
    f.append(feature[1:, :])
    
print(len(f))
print(f[1])
print(f_idx[1])
# Out:
# 20
# [[ 8.820592  -0.7952802  8.820592  ... -0.7952802 -0.7952802 -0.7952802]
#  [-1.262218   7.255175  11.24396   ... -1.262218  -1.262218  -1.262218 ]
#  [10.28912   -1.406134   9.056998  ... -1.406134  -1.406134  -1.406134 ]
#  ...
#  [10.89424   -0.6186975  8.997175  ... -0.6186975 -0.6186975 -0.6186975]
#  [10.04846   -0.7713402  9.132197  ... -0.7713402 -0.7713402 -0.7713402]
#  [11.00702   -0.8423803 10.38288   ... -0.8423803 -0.8423803 -0.8423803]]
# [41, 42, 99, 108, 191, 213, 313, 386, 423, 450, 479, 490, 506, 594, 607, 621, 648, 773, 792, 793, 871, 1090, 1122, 1133, 1134, 1136, 1150, 1187, 1260, 1291, 1292, 1370, 1371]

# %%
# indices of ten words/docs

from sklearn.metrics.pairwise import euclidean_distances
import pprint

x_bar = doc_word.mean(axis = 0)
print(x_bar.shape)
print(x_bar)
top_ten_words = []
top_ten_docs = []

for i in range(len(f)):
    m = f[i].mean(axis = 0)
    pos_dist = m - x_bar
    top_ten_words_per_cluster = np.argsort(pos_dist)[-10:]
    top_ten_words.append(list(top_ten_words_per_cluster))
    
    doc_dist = euclidean_distances(x_bar.reshape(1, -1), f[i])
    top_ten_doc_idx_in_cluster = np.argsort(doc_dist)[0][-10:]
    actual_idx = []
    for in_cluster_idx in list(top_ten_doc_idx_in_cluster):
        idx = f_idx[i][in_cluster_idx]
        actual_idx.append(idx)    
    top_ten_docs.append(actual_idx)
    
pprint.pprint(top_ten_words)
pprint.pprint(top_ten_docs)

# largest positive distance from x bar means 
# the frequency of certain word in current document 
# is much higher than the frequency of that word in average of all documents
# ie. it's current doc's "identifier" word
# Out:
# (5476,)
# [ 6.12158107  3.39409491  9.01546653 ... -0.5040002  -0.58283004
#  -0.5696959 ]
# [[371, 2636, 2340, 954, 4465, 5074, 4305, 4478, 2551, 1936],
#  [1187, 826, 1275, 237, 852, 219, 761, 163, 674, 1021],
#  [1046, 687, 876, 269, 76, 167, 436, 185, 228, 49],
#  [760, 0, 33, 5, 183, 189, 236, 23, 1, 21],
#  [3322, 887, 3011, 646, 2312, 4411, 3120, 266, 4986, 461],
#  [4629, 2210, 3643, 79, 1012, 645, 240, 1522, 444, 775],
#  [1, 162, 23, 5, 22, 14, 29, 44, 7, 17],
#  [34, 205, 76, 18, 1094, 17, 29, 49, 185, 171],
#  [34, 195, 16, 478, 315, 278, 177, 619, 164, 96],
#  [246, 979, 630, 228, 34, 167, 753, 19, 350, 444],
#  [2069, 372, 1954, 3965, 1449, 1279, 4139, 4171, 2157, 3552],
#  [582, 2358, 1981, 599, 1351, 4200, 3235, 1945, 1840, 3387],
#  [331, 39, 58, 1285, 250, 440, 270, 283, 281, 262],
#  [829, 5074, 421, 1725, 963, 1288, 1936, 1448, 2551, 2761],
#  [253, 89, 277, 128, 405, 39, 154, 0, 95, 54],
#  [750, 1134, 2270, 233, 3405, 1717, 206, 3395, 5070, 2609],
#  [962, 82, 515, 38, 451, 208, 463, 51, 396, 230],
#  [396, 384, 3201, 1636, 802, 483, 1688, 1370, 3347, 2844],
#  [125, 23, 1044, 51, 325, 22, 178, 5, 7, 1],
#  [4617, 731, 3073, 4408, 1818, 4405, 738, 2849, 1694, 210]]
# [[555],
#  [213, 792, 1133, 479, 42, 506, 99, 1134, 386, 1187],
#  [828, 1177, 1123, 739, 596, 1069, 196, 1345, 402, 1242],
#  [169, 971, 142, 1048, 271, 846, 1137, 411, 906, 217],
#  [437, 436],
#  [942, 536, 526, 152, 212, 699, 1216, 268, 1372, 385],
#  [1276, 333, 144, 740, 25, 154, 439, 326, 327, 325],
#  [1049, 215, 296, 294, 608, 1329, 930, 69, 264, 409],
#  [180, 513, 508, 741, 632, 1076, 986, 1077, 609, 631],
#  [808, 1001, 382, 805, 475, 210, 257, 649, 1348, 12],
#  [1113],
#  [989, 266, 988],
#  [535, 16, 634, 17, 18, 155, 1301, 15, 1302, 1303],
#  [824],
#  [859, 20, 636, 510, 1247, 836, 435, 1248, 1078, 216],
#  [772],
#  [1106, 243, 557, 181, 838, 717, 445, 461, 384, 837],
#  [498],
#  [701, 494, 889, 1147, 892, 869, 610, 516, 167, 165],
#  [211]]

# %%
# find actual words/titles with indices
# import json

with open('science2k-titles.txt', 'r') as f:
    titles = f.readlines()
    for i in range(len(titles)):
        titles[i] = titles[i].split("\n")[0]
    
print(len(titles))
print(titles[0])

top_doc_names = {}
for i in range(len(top_ten_docs)):
    one_doc_names = []
    for doc in top_ten_docs[i]:
        one_doc_names.append(titles[doc])
    top_doc_names[i] = one_doc_names
pprint.pprint(top_doc_names)

# with open('top_doc_names.json', 'w') as outfile:
#     json.dump(top_doc_names, outfile)
# Out:
# 1373
# "Archaeology in the Holy Land"
# {0: ['"Splitting the Chromosome: Cutting the Ties That Bind Sister '
#      'Chromatids"'],
#  1: ['"Mammalian Neural Stem Cells"',
#      '"Primates: A Natural Heritage of Conflict Resolution"',
#      '"Diversity and Dynamics of Dendritic Signaling"',
#      '"Whither the Future of Controlling Quantum Phenomena?"',
#      '"Deconstructing the Science Wars by Reconstructing an Old Mold"',
#      '"Designing a New Material World"',
#      '"AIDS as a Zoonosis: Scientific and Public Health Implications"',
#      '"Untangling Dendrites with Quantitative Models"',
#      '"How Animals Move: An Integrative View"',
#      '"Breaking down Scientific Barriers to the Study of Brain and Mind"'],
#  2: ['"A New Breed of High-Tech Detectives"',
#      '"Silent No Longer: \'Model Minority\' Mobilizes"',
#      '"Help Needed to Rebuild Science in Yugoslavia"',
#      '"The Quickening of Science Communication"',
#      '"Clones: A Hard Act to Follow"',
#      '"Presidential Forum: Gore and Bush Offer Their Views on Science"',
#      '"Meltdown on Long Island"',
#      '"Breakthrough of the Year: Genomics Comes of Age"',
#      '"A Mouse Chronology"',
#      '"Atom-Scale Research Gets Real"'],
#  3: ['"Ethanol-Induced Apoptotic Neurodegeneration and Fetal Alcohol Syndrome"',
#      '"Respiration and Parturition Affected by Conditional Overexpression of '
#      'the <latex>$Ca^{2+}$</latex>-Activated <latex>$K^+$</latex> Channel '
#      'Subunit, SK3"',
#      '"Synaptic Assembly of the Brain in the Absence of Neurotransmitter '
#      'Secretion"',
#      '"Dynamics of T Lymphocyte Responses: Intermediates, Effectors, and '
#      'Memory Cells"',
#      '"Hematopoietic Stem Cell Quiescence Maintained by '
#      '<latex>$p21^{cip1/waf1}$</latex>"',
#      '"Calcium Sensitivity of Glutamate Release in a Calyx-Type Terminal"',
#      '"Neurodegeneration Prevented by Lentiviral Vector Delivery of GDNF in '
#      'Primate Models of Parkinson\'s Disease"',
#      '"Impaired Nociception and Pain Sensation in Mice Lacking the Capsaicin '
#      'Receptor"',
#      '"Therapeutic Approaches to Bone Diseases"',
#      '"An Oral Vaccine against NMDAR1 with Efficacy in Experimental Stroke and '
#      'Epilepsy"'],
#  4: ['"Quantum Criticality: Competing Ground States in Low Dimensions"',
#      '"Advances in the Physics of High-Temperature Superconductivity"'],
#  5: ['"Printing Proteins as Microarrays for High-Throughput Function '
#      'Determination"',
#      '"Molecular Computation by DNA Hairpin Formation"',
#      '"Messages from a Mountain"',
#      '"Signals to Move Cells"',
#      '"Stem Cells in Epithelial Tissues"',
#      '"Perception of Environmental Signals by a Marine Diatom"',
#      '"Biosensors: Sense and Sensitivity"',
#      '"An Archaeal Iron-Oxidizing Extreme Acidophile Important in Acid Mine '
#      'Drainage"',
#      '"Nonlinear Dimensionality Reduction by Locally Linear Embedding"',
#      '"Motility Powered by Supramolecular Springs and Ratchets"'],
#  6: ['"How Cells Handle Cholesterol"',
#      '"A Drosophila Mechanosensory Transduction Channel"',
#      '"Signaling and Circuitry of Multiple MAPK Pathways Revealed by a Matrix '
#      'of Global Gene Expression Profiles"',
#      '"Role of the Mouse ank Gene in Control of Tissue Calcification and '
#      'Arthritis"',
#      '"Protein Interaction Mapping in C. elegans Using Proteins Involved in '
#      'Vulval Development"',
#      '"Conservation and Novelty in the Evolution of Cell Adhesion and '
#      'Extracellular Matrix Genes"',
#      '"Positional Syntenic Cloning and Functional Characterization of the '
#      'Mammalian Circadian Mutation tau"',
#      '"A Whole-Genome Assembly of Drosophila"',
#      '"Comparative Genomics of the Eukaryotes"',
#      '"The Genome Sequence of Drosophila melanogaster"'],
#  7: ['"The Ins and Outs of Body Surface Immunology"',
#      '"Translating Stem and Progenitor Cell Biology to the Clinic: Barriers '
#      'and Opportunities"',
#      '"Mechanism-Based Target Identification and Drug Discovery in Cancer '
#      'Research"',
#      '"Drug Discovery: A Historical Perspective"',
#      '"Cloning: Pathways to a Pluripotent Future"',
#      '"The Ecological Risks and Benefits of Genetically Engineered Plants"',
#      '"The Incredible Life and Times of Biological Cells"',
#      '"Emerging Infectious Diseases of Wildlife-Threats to Biodiversity and '
#      'Human Health"',
#      '"Genomics: Journey to the Center of Biology"',
#      '"Infectious History"'],
#  8: ['"Interpreting Differential Temperature Trends at the Surface and in the '
#      'Lower Troposphere"',
#      '"Reduction of Tropical Cloudiness by Soot"',
#      '"Earliest Pleistocene Hominid Cranial Remains from Dmanisi, Republic of '
#      'Georgia: Taxonomy, Geological Setting, and Age"',
#      '"Causes of Climate Change over the past 1000 Years"',
#      '"Is El Nino Changing?"',
#      '"The Global Carbon Cycle: A Test of Our Knowledge of Earth as a System"',
#      '"Climate Extremes: Observations, Modeling, and Impacts"',
#      '"The Ascent of Atmospheric Sciences"',
#      '"Timing the Ancestor of the HIV-1 Pandemic Strains"',
#      '"Status and Improvements of Coupled General Circulation Models"'],
#  9: ['"Preservation of DNA from Endangered Species"',
#      '"CERN\'s Gamble Shows Perils, Rewards of Playing the Odds"',
#      '"In Nature, Animals That Stop and Start Win the Race"',
#      '"A Wetter, Younger Mars Emerging"',
#      '"Surveying the SBIR Program"',
#      '"Europe Confronts the Embryonic Stem Cell Research Challenge"',
#      '"An Appealing Snowball Earth That\'s Still Hard to Swallow"',
#      '"Cool Comets, Barren Clusters, and a Maxed-Out Universe"',
#      '"Geologists Pursue Solar System\'s Oldest Relics"',
#      '"A Crushing End for Our Galaxy"'],
#  10: ['"Dimer Preparation That Mimics the Transition State for the Adsorption '
#       'of <latex>$H_2$</latex> on the Si(100)-2 x 1 Surface"'],
#  11: ['"The Shape of 433 Eros from the NEAR-Shoemaker Laser Rangefinder"',
#       '"Internal Structure and Early Thermal Evolution of Mars from Mars '
#       'Global Surveyor Topography and Gravity"',
#       '"NEAR at Eros: Imaging and Spectral Results"'],
#  12: ['"Rocks from the Mantle Transition Zone: Majorite-Bearing Xenoliths from '
#       'Malaita, Southwest Pacific"',
#       '"The Dark Halo of the Milky Way"',
#       '"Earth\'s Core and the Geodynamo"',
#       '"The Baryon Halo of the Milky Way: A Fossil Record of Its Formation"',
#       '"The Galactic Center: An Interacting System of Unusual Sources"',
#       '"Planetary Science: A Space Odyssey"',
#       '"Subduction and Slab Detachment in the Mediterranean-Carpathian Region"',
#       '"The Formation and Early Evolution of the Milky Way Galaxy"',
#       '"Piecing Together the Biggest Puzzle of All"',
#       '"Sedimentary Rocks of Early Mars"'],
#  13: ['"Pol k: A DNA Polymerase Required for Sister Chromatid Cohesion"'],
#  14: ['"Formation, Stability, and Breakup of Nanojets"',
#       '"Generating Solitons by Phase Engineering of a Bose-Einstein '
#       'Condensate"',
#       '"Negative Poisson\'s Ratios for Extreme States of Matter"',
#       '"Structure of the Hydrated <latex>$\\alpha-Al_2O_3$</latex> (0001) '
#       'Surface"',
#       '"From Micro- to Nanofabrication with Soft Materials"',
#       '"One Hundred Years of Quantum Physics"',
#       '"Orbital Physics in Transition-Metal Oxides"',
#       '"Microfabricating Conjugated Polymer Actuators"',
#       '"Blue-Fluorescent Antibodies"',
#       '"The Atom-Cavity Microscope: Single Atoms Bound in Orbit by Single '
#       'Photons"'],
#  15: ['"Group II Introns Designed to Insert into Therapeutically Relevant DNA '
#       'Target Sites in Human Cells"'],
#  16: ['"Structure of a Glycerol-Conducting Channel and the Basis for Its '
#       'Selectivity"',
#       '"The Catalytic Pathway of Cytochrome P450cam at Atomic Resolution"',
#       '"Structure of the Light-Driven Chloride Pump Halorhodopsin at 1.8 '
#       '<latex>$\\AA$</latex> Resolution"',
#       '"Crystal Structure of the Ribonucleoprotein Core of the Signal '
#       'Recognition Particle"',
#       '"The Structural Basis of Ribosome Activity in Peptide Bond Synthesis"',
#       '"Three-Dimensional Structure of the Tn5 Synaptic Complex Transposition '
#       'Intermediate"',
#       '"A Structural Framework for Deciphering the Link between '
#       '<latex>$I-A^{g7}$</latex> and Autoimmune Diabetes"',
#       '"Architecture of RNA Polymerase II and Implications for the '
#       'Transcription Mechanism"',
#       '"The Way Things Move: Looking under the Hood of Molecular Motor '
#       'Proteins"',
#       '"The Complete Atomic Structure of the Large Ribosomal Subunit at 2.4 '
#       '<latex>$\\AA$</latex> Resolution"'],
#  17: ['"Gene Therapy on Trial"'],
#  18: ['"Requirement for RORg in Thymocyte Survival and Lymphoid Organ '
#       'Development"',
#       '"Requirement of JNK for Stress-Induced Activation of the Cytochrome '
#       'c-Mediated Death Pathway"',
#       '"Differential Clustering of CD4 and CD3z during T Cell Recognition"',
#       '"Integration of Multiple Signals through Cooperative Regulation of the '
#       'N-WASP-Arp2/3 Complex"',
#       '"Regulated Cleavage of a Contact-Mediated Axon Repellent"',
#       '"Genes Expressed in Human Tumor Endothelium"',
#       '"Kinesin Superfamily Motor Protein KIF17 and mLin-10 in NMDA '
#       'Receptor-Containing Vesicle Transport"',
#       '"Noxa, a BH3-Only Member of the Bcl-2 Family and Candidate Mediator of '
#       'p53-Induced Apoptosis"',
#       '"Central Role for G Protein-Coupled Phosphoinositide 3-Kinase g in '
#       'Inflammation"',
#       '"Function of PI3Kg in Thymocyte Development, T Cell Activation, and '
#       'Neutrophil Migration"'],
#  19: ['"Out of Eden: Stem Cells and Their Niches"']}

# %%
with open('science2k-vocab.txt', 'r') as f:
    words = f.readlines()
    for i in range(len(words)):
        words[i] = words[i].split("\n")[0]
    
print(len(words))
print(words[0])

top_words = {}
for i in range(len(top_ten_words)):
    one_doc_words = []
    for doc in top_ten_words[i]:
        one_doc_words.append(words[doc])
    top_words[i] = one_doc_words
pprint.pprint(top_words)
# Out:
# 5476
# fig
# {0: ['chromosome',
#      'spindle',
#      'mitotic',
#      'chromosomes',
#      'metaphase',
#      'chromatid',
#      'anaphase',
#      'chromatids',
#      'cohesion',
#      'sister'],
#  1: ['stimulus',
#      'processing',
#      'task',
#      'responses',
#      'stimuli',
#      'significant',
#      'neural',
#      'brain',
#      'cortex',
#      'visual'],
#  2: ['say',
#      'working',
#      'get',
#      'just',
#      'year',
#      'national',
#      'people',
#      'researchers',
#      'scientists',
#      'says'],
#  3: ['staining',
#      'fig',
#      'control',
#      'cell',
#      'mouse',
#      'days',
#      'day',
#      'expression',
#      'cells',
#      'mice'],
#  4: ['superconducting',
#      'scattering',
#      'ordering',
#      'charge',
#      'fermi',
#      'superconductivity',
#      'spins',
#      'quantum',
#      'quasiparticle',
#      'spin'],
#  5: ['perspectives',
#      'investigators',
#      'cgi',
#      'see',
#      'authors',
#      'issue',
#      'figure',
#      'author',
#      'mail',
#      'page'],
#  6: ['cells',
#      'sequences',
#      'expression',
#      'cell',
#      'proteins',
#      'dna',
#      'genes',
#      'sequence',
#      'protein',
#      'gene'],
#  7: ['years',
#      'genetic',
#      'year',
#      'new',
#      'team',
#      'gene',
#      'genes',
#      'says',
#      'researchers',
#      'disease'],
#  8: ['years',
#      'climate',
#      'surface',
#      'atmospheric',
#      'ocean',
#      'north',
#      'global',
#      'estimates',
#      'period',
#      'values'],
#  9: ['sciences',
#      'compass',
#      'focus',
#      'scientists',
#      'years',
#      'national',
#      'news',
#      'research',
#      'scientific',
#      'mail'],
#  10: ['coefficient',
#       'atoms',
#       'configuration',
#       'kcal',
#       'barrier',
#       'filled',
#       'adsorption',
#       'bare',
#       'dimer',
#       'dimers'],
#  11: ['variations',
#       'spacecraft',
#       'gravitational',
#       'impact',
#       'hemisphere',
#       'topographic',
#       'longitude',
#       'crater',
#       'gravity',
#       'topography'],
#  12: ['temperatures',
#       'temperature',
#       'field',
#       'planet',
#       'processes',
#       'dark',
#       'resolution',
#       'observations',
#       'earth',
#       'material'],
#  13: ['lanes',
#       'chromatid',
#       'replication',
#       'primer',
#       'polymerase',
#       'pol',
#       'sister',
#       'template',
#       'cohesion',
#       'trf4'],
#  14: ['solid',
#       'density',
#       'measurements',
#       'measured',
#       'optical',
#       'temperature',
#       'shows',
#       'fig',
#       'electron',
#       'energy'],
#  15: ['donor',
#       'plasmid',
#       'pairing',
#       'target',
#       'recipient',
#       'mobility',
#       'hiv',
#       'introns',
#       'ccr5',
#       'intron'],
#  16: ['chains',
#       'domain',
#       'loop',
#       'structure',
#       'conserved',
#       'side',
#       'helix',
#       'binding',
#       'crystal',
#       'residues'],
#  17: ['crystal',
#       'patients',
#       'doses',
#       'rac',
#       'liver',
#       'vector',
#       'trial',
#       'therapy',
#       'wilson',
#       'adenovirus'],
#  18: ['hours',
#       'expression',
#       'incubated',
#       'binding',
#       'antibody',
#       'proteins',
#       'min',
#       'cell',
#       'protein',
#       'cells'],
#  19: ['notch',
#       'tissues',
#       'asymmetry',
#       'divisions',
#       'differentiated',
#       'daughter',
#       'differentiation',
#       'fate',
#       'asymmetric',
#       'stem']}

# %% [markdown]
# ### Load data and K-means on word-doc

# %%
import numpy as np
word_doc = np.load("science2k-word-doc.npy")
print(word_doc.shape)

k = 20
kmeans = KMeans(n_clusters=k, random_state=0).fit(word_doc)
# Out:
# (5476, 1373)

# %%
# construct test feature and corresponding label list

f2 = []
f2_idx = []
for i in range(k):
    indices = np.where(kmeans.labels_ == i)
    f2_idx.append(list(indices[0]))
    feature = np.zeros(word_doc.shape[1])
    for idx in indices:
        feature = np.vstack((feature, word_doc[idx]))
    f2.append(feature[1:, :])
    
print(len(f2))
print(f2[1])
print(f2_idx[1])

# for terms in each cluster, they are similar in the way that each term appears in a similar range of docs
# each cluster will have more terms than docs, so f2[i].shape[0] and len(f2_idx[i]) will be larger
# Out:
# 20
# [[-2.090192  -2.090192  -2.090192  ... -2.090192  -2.090192  -2.090192 ]
#  [ 6.187139  -2.330254  -2.330254  ... -2.330254  -2.330254  -2.330254 ]
#  [-1.830366  -1.830366  -1.830366  ... -1.830366  -1.830366  -1.830366 ]
#  ...
#  [-0.1584664 -0.1584664 -0.1584664 ... -0.1584664 -0.1584664 -0.1584664]
#  [-0.1928384 -0.1928384 -0.1928384 ... -0.1928384 -0.1928384 -0.1928384]
#  [-0.1124251 -0.1124251 -0.1124251 ... -0.1124251 -0.1124251 -0.1124251]]
# [72, 147, 151, 164, 177, 188, 195, 207, 247, 268, 278, 281, 282, 296, 297, 314, 315, 337, 364, 393, 412, 433, 478, 486, 501, 502, 507, 521, 524, 561, 562, 567, 582, 601, 611, 615, 619, 644, 652, 655, 661, 662, 664, 666, 689, 694, 713, 716, 723, 740, 742, 743, 748, 752, 758, 770, 774, 777, 780, 781, 805, 807, 825, 836, 845, 850, 863, 878, 881, 886, 889, 892, 893, 896, 909, 921, 923, 939, 947, 966, 977, 1029, 1036, 1068, 1078, 1088, 1093, 1143, 1164, 1190, 1206, 1225, 1231, 1241, 1259, 1260, 1267, 1283, 1284, 1285, 1293, 1296, 1317, 1322, 1332, 1333, 1341, 1351, 1355, 1364, 1384, 1391, 1395, 1399, 1407, 1414, 1418, 1432, 1433, 1445, 1451, 1475, 1489, 1499, 1541, 1554, 1573, 1575, 1585, 1591, 1618, 1619, 1628, 1632, 1645, 1655, 1659, 1661, 1669, 1683, 1698, 1699, 1704, 1714, 1718, 1728, 1729, 1742, 1784, 1801, 1817, 1821, 1823, 1838, 1883, 1884, 1885, 1895, 1905, 1909, 1972, 1983, 1984, 1985, 1990, 1991, 2001, 2008, 2037, 2086, 2109, 2132, 2136, 2145, 2154, 2159, 2190, 2222, 2227, 2231, 2244, 2280, 2284, 2290, 2324, 2329, 2346, 2354, 2378, 2379, 2386, 2388, 2404, 2414, 2443, 2461, 2463, 2474, 2484, 2493, 2498, 2499, 2519, 2523, 2531, 2541, 2555, 2567, 2586, 2591, 2596, 2601, 2608, 2611, 2620, 2649, 2662, 2666, 2678, 2684, 2703, 2717, 2744, 2829, 2846, 2927, 2942, 2976, 3042, 3056, 3111, 3172, 3185, 3187, 3223, 3235, 3289, 3301, 3325, 3340, 3363, 3369, 3372, 3407, 3428, 3466, 3498, 3503, 3531, 3569, 3611, 3663, 3671, 3732, 3754, 3783, 3858, 3883, 3891, 3917, 3945, 4094, 4134, 4150, 4198, 4223, 4246, 4300, 4354, 4385, 4443, 4464, 4528, 4537, 4570, 4589, 4654, 4670, 4774, 4776, 4828, 4874, 4884, 4953, 5114, 5134, 5157, 5192, 5354]

# %%
# predict indices of ten words/docs

x2_bar = word_doc.mean(axis = 0)
print(x2_bar.shape)
print(x2_bar)
top_ten_words2 = []
top_ten_docs2 = []

for i in range(len(f2)):
    m = f2[i].mean(axis = 0)
    pos_dist = m - x2_bar
    top_ten_docs_per_cluster = np.argsort(pos_dist)[-10:]
    top_ten_docs2.append(list(top_ten_docs_per_cluster))
    
    word_dist = euclidean_distances(x2_bar.reshape(1, -1), f2[i])
    top_ten_word_idx_in_cluster = np.argsort(word_dist)[0][-10:]
    actual_idx = []
    for in_cluster_idx in list(top_ten_word_idx_in_cluster):
        idx = f2_idx[i][in_cluster_idx]
        actual_idx.append(idx)    
    top_ten_words2.append(actual_idx)
    
pprint.pprint(top_ten_words2)
pprint.pprint(top_ten_docs2)

# largest positive distance from x bar means 
# the frequency of certain doc which the current term appears in
# is much higher than the frequency of that doc which average term appears in
# ie. it's current term's "most salient" doc
# Out:
# (1373,)
# [-0.38194837 -0.34658092 -0.27070615 ...  0.13722999  0.20827001
#   0.11868435]
# [[714, 676, 682, 440, 319, 953, 258, 956, 588, 809],
#  [412, 268, 151, 207, 177, 297, 314, 72, 164, 147],
#  [1191, 1434, 1356, 928, 906, 638, 787, 1145, 1012, 400],
#  [469, 434, 326, 137, 205, 67, 29, 14, 28, 17],
#  [83, 22, 63, 59, 56, 42, 33, 7, 5, 1],
#  [71, 127, 102, 50, 15, 48, 36, 47, 45, 16],
#  [144],
#  [484, 403, 358, 64, 24, 20, 0],
#  [55],
#  [97, 27, 135, 130, 88, 168, 75, 79, 18, 19],
#  [76, 34],
#  [741, 113, 678, 203, 252, 530, 162, 301, 321, 70],
#  [101, 182, 126, 109, 90, 60, 92, 84, 57, 8],
#  [1026, 683, 1099, 338, 586, 791, 621, 705, 279, 227],
#  [2676, 2794, 1680, 1412, 979, 444, 246],
#  [186, 217, 201, 105, 26, 91, 78, 98, 65, 68],
#  [497, 454, 406, 236, 353, 133, 200, 134, 103, 35],
#  [213],
#  [74, 32, 38, 40, 69, 52, 6, 41, 37, 31],
#  [198]]
# [[216, 16, 1302, 636, 17, 435, 15, 436, 437, 18],
#  [741, 1076, 135, 931, 1303, 986, 1307, 672, 913, 631],
#  [376, 759, 236, 46, 830, 289, 519, 709, 710, 499],
#  [492, 144, 957, 399, 821, 60, 439, 274, 368, 225],
#  [507, 217, 167, 494, 255, 165, 495, 439, 516, 892],
#  [156, 988, 991, 1277, 186, 636, 742, 216, 435, 436],
#  [1301, 539, 1344, 1370, 421, 135, 747, 508, 931, 83],
#  [398, 1315, 1340, 189, 389, 539, 1334, 893, 1225, 229],
#  [410, 804, 988, 590, 667, 668, 471, 1140, 460, 20],
#  [596, 171, 973, 1347, 1069, 1177, 1123, 1242, 196, 402],
#  [145, 512, 465, 619, 338, 1338, 360, 110, 642, 937],
#  [327, 823, 1288, 824, 516, 448, 181, 610, 439, 325],
#  [846, 1122, 1313, 1187, 44, 1370, 411, 1133, 1134, 51],
#  [1107, 173, 609, 1177, 1045, 1324, 1320, 1321, 1322, 1323],
#  [456, 457, 455, 352, 1126, 550, 284, 1155, 1157, 1156],
#  [609, 297, 327, 479, 409, 986, 1329, 631, 386, 1187],
#  [228, 211, 905, 215, 217, 1046, 187, 906, 167, 165],
#  [691, 785, 62, 430, 371, 1213, 429, 1132, 613, 244],
#  [365, 813, 55, 1303, 181, 325, 838, 717, 461, 837],
#  [728, 773, 170, 32, 133, 411, 602, 751, 310, 1202]]

# %%
# find actual words/titles with indices

top_doc_names2 = {}
for i in range(len(top_ten_docs2)):
    one_doc_names = []
    for doc in top_ten_docs2[i]:
        one_doc_names.append(titles[doc])
    top_doc_names2[i] = one_doc_names
pprint.pprint(top_doc_names2)
# Out:
# {0: ['"The Atom-Cavity Microscope: Single Atoms Bound in Orbit by Single '
#      'Photons"',
#      '"The Dark Halo of the Milky Way"',
#      '"Piecing Together the Biggest Puzzle of All"',
#      '"Negative Poisson\'s Ratios for Extreme States of Matter"',
#      '"The Baryon Halo of the Milky Way: A Fossil Record of Its Formation"',
#      '"Orbital Physics in Transition-Metal Oxides"',
#      '"The Formation and Early Evolution of the Milky Way Galaxy"',
#      '"Advances in the Physics of High-Temperature Superconductivity"',
#      '"Quantum Criticality: Competing Ground States in Low Dimensions"',
#      '"The Galactic Center: An Interacting System of Unusual Sources"'],
#  1: ['"Causes of Climate Change over the past 1000 Years"',
#      '"The Global Carbon Cycle: A Test of Our Knowledge of Earth as a System"',
#      '"Cool Glacial Temperatures and Changes in Moisture Source Recorded in '
#      'Oman Groundwaters"',
#      '"Climate Impact of Late Quaternary Equatorial Pacific Sea Surface '
#      'Temperature Variations"',
#      '"Sedimentary Rocks of Early Mars"',
#      '"Climate Extremes: Observations, Modeling, and Impacts"',
#      '"Rapid Changes in the Hydrologic Cycle of the Tropical Atlantic during '
#      'the Last Glacial"',
#      '"Coherent High- and Low-Latitude Climate Variability during the Holocene '
#      'Warm Period"',
#      '"A 22,000-Year Record of Monsoonal Precipitation from Northern Chile\'s '
#      'Atacama Desert"',
#      '"Status and Improvements of Coupled General Circulation Models"'],
#  2: ['"Scientists at Brookhaven"',
#      '"The Holey Grail of General Intelligence"',
#      '"Statistics of Ancestral Roots"',
#      '"Influences of Dietary Uptake and Reactive Sulfides on Metal '
#      'Bioavailability from Aquatic Sediments"',
#      '"Biological Control of Invading Species"',
#      '"Limbless Tetrapods and Snakes with Legs"',
#      '"Algorithmic Gladiators Vie for Digital Glory"',
#      '"Corrections and Clarifications: Timing the Ancestor of the HIV-1 '
#      'Pandemic Strains"',
#      '"Corrections and Clarifications: Absorbing Phenomena"',
#      '"National Academy of Sciences Elects New Members"'],
#  3: ['"Template Boundary in a Yeast Telomerase Specified by RNA Structure"',
#      '"Signaling and Circuitry of Multiple MAPK Pathways Revealed by a Matrix '
#      'of Global Gene Expression Profiles"',
#      '"Genetic Testing: Present and Future"',
#      '"Positioning of Longitudinal Nerves in C. elegans by Nidogen"',
#      '"CikA, a Bacteriophytochrome That Resets the Cyanobacterial Circadian '
#      'Clock"',
#      '"Regulation of JNK by Src during Drosophila Development"',
#      '"Positional Syntenic Cloning and Functional Characterization of the '
#      'Mammalian Circadian Mutation tau"',
#      '"Gridlock, an HLH Gene Required for Assembly of the Aorta in Zebrafish"',
#      '"Genetic Requirements for Inheritance of RNAi in C. elegans"',
#      '"Effects of Environment on Compensatory Mutations to Ameliorate Costs of '
#      'Antibiotic Resistance"'],
#  4: ['"Interacting Molecular Loops in the Mammalian Circadian Clock"',
#      '"An Oral Vaccine against NMDAR1 with Efficacy in Experimental Stroke and '
#      'Epilepsy"',
#      '"Central Role for G Protein-Coupled Phosphoinositide 3-Kinase g in '
#      'Inflammation"',
#      '"Requirement of JNK for Stress-Induced Activation of the Cytochrome '
#      'c-Mediated Death Pathway"',
#      '"Dual Signaling Regulated by Calcyon, a D1 Dopamine Receptor Interacting '
#      'Protein"',
#      '"Function of PI3Kg in Thymocyte Development, T Cell Activation, and '
#      'Neutrophil Migration"',
#      '"Ubiquitin Protein Ligase Activity of IAPs and Their Degradation in '
#      'Proteasomes in Response to Apoptotic Stimuli"',
#      '"Positional Syntenic Cloning and Functional Characterization of the '
#      'Mammalian Circadian Mutation tau"',
#      '"Noxa, a BH3-Only Member of the Bcl-2 Family and Candidate Mediator of '
#      'p53-Induced Apoptosis"',
#      '"Regulated Cleavage of a Contact-Mediated Axon Repellent"'],
#  5: ['"Observation of Antiferromagnetic Domains in Epitaxial Thin Films"',
#      '"NEAR at Eros: Imaging and Spectral Results"',
#      '"The Kondo Effect in the Unitary Limit"',
#      '"Self-Mode-Locking of Quantum Cascade Lasers with Giant Ultrafast '
#      'Optical Nonlinearities"',
#      '"Density of Phonon States in Iron at High Pressure"',
#      '"Negative Poisson\'s Ratios for Extreme States of Matter"',
#      '"Signature of Superfluid Density in the Single-Particle Excitation '
#      'Spectrum of <latex>$Bi_2Sr_2CaCu_2O_{8+\\delta}$</latex>"',
#      '"The Atom-Cavity Microscope: Single Atoms Bound in Orbit by Single '
#      'Photons"',
#      '"Orbital Physics in Transition-Metal Oxides"',
#      '"Advances in the Physics of High-Temperature Superconductivity"'],
#  6: ['"Subduction and Slab Detachment in the Mediterranean-Carpathian Region"',
#      '"The Spin Excitation Spectrum in Superconducting '
#      '<latex>$YBa_2Cu_3O_{6.85}$</latex>"',
#      '"Functional Requirement for Class I MHC in CNS Development and '
#      'Plasticity"',
#      '"Cholinergic Enhancement and Increased Selectivity of Perceptual '
#      'Processing during Working Memory"',
#      '"The Outcome of Acute Hepatitis C Predicted by the Evolution of the '
#      'Viral Quasispecies"',
#      '"Cool Glacial Temperatures and Changes in Moisture Source Recorded in '
#      'Oman Groundwaters"',
#      '"ORCA3, a Jasmonate-Responsive Transcriptional Regulator of Plant '
#      'Primary and Secondary Metabolism"',
#      '"Earliest Pleistocene Hominid Cranial Remains from Dmanisi, Republic of '
#      'Georgia: Taxonomy, Geological Setting, and Age"',
#      '"Climate Impact of Late Quaternary Equatorial Pacific Sea Surface '
#      'Temperature Variations"',
#      '"Role of the Enteric Nervous System in the Fluid and Electrolyte '
#      'Secretion of Rotavirus Diarrhea"'],
#  7: ['"Specification of Drosophila Hematopoietic Lineage by Conserved '
#      'Transcription Factors"',
#      '"Multigenerational Cortical Inheritance of the Rax2 Protein in Orienting '
#      'Polarity and Division in Yeast"',
#      '"Docosahexaenoic Acid, a Ligand for the Retinoid X Receptor in Mouse '
#      'Brain"',
#      '"The Glucocorticoid Receptor: Rapid Exchange with Regulatory Sites in '
#      'Living Cells"',
#      '"Chain Mobility in the Amorphous Region of Nylon 6 Observed under Active '
#      'Uniaxial Deformation"',
#      '"The Spin Excitation Spectrum in Superconducting '
#      '<latex>$YBa_2Cu_3O_{6.85}$</latex>"',
#      '"Molybdenum Nanowires by Electrodeposition"',
#      '"Function of an Axonal Chemoattractant Modulated by Metalloprotease '
#      'Activity"',
#      '"Protection against Cutaneous Leishmaniasis Resulting from Bites of '
#      'Uninfected Sand Flies"',
#      '"General Acid-Base Catalysis in the Mechanism of a Hepatitis Delta Virus '
#      'Ribozyme"'],
#  8: ['"Experiments and Simulations of Ion-Enhanced Interfacial Chemistry on '
#      'Aqueous NaCl Aerosols"',
#      '"Synaptic Integration Mediated by Striatal Cholinergic Interneurons in '
#      'Basal Ganglia Function"',
#      '"NEAR at Eros: Imaging and Spectral Results"',
#      '"Uninterrupted MCM2-7 Function Required for DNA Replication Fork '
#      'Progression"',
#      '"A Ferroelectric Liquid Crystal Conglomerate Composed of Racemic '
#      'Molecules"',
#      '"An Orientational Transition of Bent-Core Molecules in an Anisotropic '
#      'Matrix"',
#      '"Resetting Central and Peripheral Circadian Oscillators in Transgenic '
#      'Rats"',
#      '"Phase Evolution in a Kondo-Correlated System"',
#      '"Carrier-Envelope Phase Control of Femtosecond Mode-Locked Lasers and '
#      'Direct Optical Frequency Synthesis"',
#      '"Generating Solitons by Phase Engineering of a Bose-Einstein '
#      'Condensate"'],
#  9: ['"Clones: A Hard Act to Follow"',
#      '"Ecologists on a Mission to Save the World"',
#      '"Soft Money\'s Hard Realities"',
#      '"I\'d like to See America Used as a Global Lab"',
#      '"Presidential Forum: Gore and Bush Offer Their Views on Science"',
#      '"Silent No Longer: \'Model Minority\' Mobilizes"',
#      '"Help Needed to Rebuild Science in Yugoslavia"',
#      '"Atom-Scale Research Gets Real"',
#      '"Meltdown on Long Island"',
#      '"A Mouse Chronology"'],
#  10: ['"Balancing the Science Budget"',
#       '"El Nino: Like Climate Teleconnections in New England during the Late '
#       'Pleistocene"',
#       '"Heightened Odds of Large Earthquakes near Istanbul: An '
#       'Interaction-Based Probability Calculation"',
#       '"Economic Incentives for Rain Forest Conservation across Scales"',
#       '"Simulation of Early 20th Century Global Warming"',
#       '"External Control of 20th Century Temperature by Natural and '
#       'Anthropogenic Forcings"',
#       '"Global Carbon Sinks and Their Variability Inferred from Atmospheric '
#       '<latex>$O_2$</latex> and <latex>$\\delta^{13}C$</latex>"',
#       '"A Tale of Two Futures: HIV and Antiretroviral Therapy in San '
#       'Francisco"',
#       '"Impacts of a Global Climate Cycle on Population Dynamics of a '
#       'Migratory Songbird"',
#       '"Historical Trends in Lake and River Ice Cover in the Northern '
#       'Hemisphere"'],
#  11: ['"Comparative Genomics of the Eukaryotes"',
#       '"Pif1p Helicase, a Catalytic Inhibitor of Telomerase in Yeast"',
#       '"Accumulation of Dietary Cholesterol in Sitosterolemia Caused by '
#       'Mutations in Adjacent ABC Transporters"',
#       '"Pol k: A DNA Polymerase Required for Sister Chromatid Cohesion"',
#       '"Noxa, a BH3-Only Member of the Bcl-2 Family and Candidate Mediator of '
#       'p53-Induced Apoptosis"',
#       '"Homologs of Small Nucleolar RNAs in Archaea"',
#       '"Crystal Structure of the Ribonucleoprotein Core of the Signal '
#       'Recognition Particle"',
#       '"Kinesin Superfamily Motor Protein KIF17 and mLin-10 in NMDA '
#       'Receptor-Containing Vesicle Transport"',
#       '"Positional Syntenic Cloning and Functional Characterization of the '
#       'Mammalian Circadian Mutation tau"',
#       '"The Genome Sequence of Drosophila melanogaster"'],
#  12: ['"Calcium Sensitivity of Glutamate Release in a Calyx-Type Terminal"',
#       '"Learning-Induced LTP in Neocortex"',
#       '"The Contribution of Noise to Contrast Invariance of Orientation Tuning '
#       'in Cat Visual Cortex"',
#       '"Breaking down Scientific Barriers to the Study of Brain and Mind"',
#       '"Organizing Principles for a Diversity of GABAergic Interneurons and '
#       'Synapses in the Neocortex"',
#       '"Cholinergic Enhancement and Increased Selectivity of Perceptual '
#       'Processing during Working Memory"',
#       '"Impaired Nociception and Pain Sensation in Mice Lacking the Capsaicin '
#       'Receptor"',
#       '"Diversity and Dynamics of Dendritic Signaling"',
#       '"Untangling Dendrites with Quantitative Models"',
#       '"Distal Initiation and Active Propagation of Action Potentials in '
#       'Interneuron Dendrites"'],
#  13: ['"Control of Viremia and Prevention of Clinical AIDS in Rhesus Monkeys '
#       'by Cytokine-Augmented DNA Vaccination"',
#       '"Restoration-A Misnomer?"',
#       '"Timing the Ancestor of the HIV-1 Pandemic Strains"',
#       '"Silent No Longer: \'Model Minority\' Mobilizes"',
#       '"Computers Aid Vaccine Design"',
#       '"Corrections and Clarifications: Optically Defined Multifunctional '
#       'Patterning of Photosensitive Thin-Film Silica Mesophases"',
#       '"Corrections and Clarifications: Surveillance and Privacy"',
#       '"Corrections and Clarifications: Thoughts on the Causes of Tree '
#       'Mortality in Appalachia"',
#       '"Corrections and Clarifications: Nitrogen on the Moon"',
#       '"Corrections and Clarifications: Invasive Plants versus Their New and '
#       'Old Neighbors: A Mechanism for Exotic Invasion"'],
#  14: ['"Corrections and Clarifications: \'Faster, Cheaper, Better\' on Trial"',
#       '"Corrections and Clarifications: Close Encounters: Details Veto Depth '
#       'from Shadows"',
#       '"Corrections and Clarifications: Marking Time for a Kingdom"',
#       '"Close Encounters: Details Veto Depth from Shadows"',
#       '"Ideas about the Surface Runoff Features on Mars"',
#       '"Immortality, Anyone?"',
#       '"Hydrogen Storage in Nanotubes"',
#       '"Corrections and Clarifications: New Brain Cells Prompt New Theory of '
#       'Depression"',
#       '"Corrections and Clarifications: Aging, Chromatin, and Food '
#       'Restriction: Connecting the Dots"',
#       '"Corrections and Clarifications: Molecular and Neuronal Substrate for '
#       'the Selective Attenuation of Anxiety"'],
#  15: ['"Timing the Ancestor of the HIV-1 Pandemic Strains"',
#       '"Harnessing the Power of the Genome in the Search for New Antibiotics"',
#       '"Comparative Genomics of the Eukaryotes"',
#       '"Whither the Future of Controlling Quantum Phenomena?"',
#       '"Infectious History"',
#       '"Climate Extremes: Observations, Modeling, and Impacts"',
#       '"The Ecological Risks and Benefits of Genetically Engineered Plants"',
#       '"Status and Improvements of Coupled General Circulation Models"',
#       '"How Animals Move: An Integrative View"',
#       '"Breaking down Scientific Barriers to the Study of Brain and Mind"'],
#  16: ['"Regulation of Cell Fate Decision of Undifferentiated Spermatogonia by '
#       'GDNF"',
#       '"Out of Eden: Stem Cells and Their Niches"',
#       '"Bone Resorption by Osteoclasts"',
#       '"Translating Stem and Progenitor Cell Biology to the Clinic: Barriers '
#       'and Opportunities"',
#       '"An Oral Vaccine against NMDAR1 with Efficacy in Experimental Stroke '
#       'and Epilepsy"',
#       '"Immune Inhibitory Receptors"',
#       '"Inhibition of Experimental Liver Cirrhosis in Mice by Telomerase Gene '
#       'Delivery"',
#       '"Therapeutic Approaches to Bone Diseases"',
#       '"Central Role for G Protein-Coupled Phosphoinositide 3-Kinase g in '
#       'Inflammation"',
#       '"Function of PI3Kg in Thymocyte Development, T Cell Activation, and '
#       'Neutrophil Migration"'],
#  17: ['"Microrobots for Micrometer-Size Objects in Aqueous Media: Potential '
#       'Tools for Single-Cell Manipulation"',
#       '"Weird Gold Nanowires"',
#       '"New Age Semiconductors Pick up the Pace"',
#       '"Shape Persistence of Synthetic Polymers"',
#       '"\'Faster, Cheaper, Better\' on Trial"',
#       '"Putting a New Spin on Carbon Nanotubes"',
#       '"Astronomy and the Degrading Environment"',
#       '"Synapses Call the Shots"',
#       '"A Nanoplotter with Both Parallel and Serial Writing Capabilities"',
#       '"Mid-Pleistocene Acheulean-like Stone Technology of the Bose Basin, '
#       'South China"'],
#  18: ['"Structure of the RNA Polymerase Domain of E. coli Primase"',
#       '"Crystal Structure of Rhodopsin: A G Protein-Coupled Receptor"',
#       '"Crystal Structure of gd T Cell Receptor Ligand T22: A Truncated '
#       'MHC-like Fold"',
#       '"Sedimentary Rocks of Early Mars"',
#       '"Crystal Structure of the Ribonucleoprotein Core of the Signal '
#       'Recognition Particle"',
#       '"The Genome Sequence of Drosophila melanogaster"',
#       '"The Structural Basis of Ribosome Activity in Peptide Bond Synthesis"',
#       '"Three-Dimensional Structure of the Tn5 Synaptic Complex Transposition '
#       'Intermediate"',
#       '"Architecture of RNA Polymerase II and Implications for the '
#       'Transcription Mechanism"',
#       '"The Complete Atomic Structure of the Large Ribosomal Subunit at 2.4 '
#       '<latex>$\\AA$</latex> Resolution"'],
#  19: ['"Molecular Identification of a Taste Receptor Gene for Trehalose in '
#       'Drosophila"',
#       '"A Neural Basis for General Intelligence"',
#       '"Evidence for DNA Loss as a Determinant of Genome Size"',
#       '"Stat3-Mediated Transformation of NIH-3T3 Cells by the Constitutively '
#       'Active Q205L <latex>$G\\alpha_o$</latex> Protein"',
#       '"High-Speed Electrically Actuated Elastomers with Strain Greater Than '
#       '100%"',
#       '"Impaired Nociception and Pain Sensation in Mice Lacking the Capsaicin '
#       'Receptor"',
#       '"Preventing Cervical Cancer"',
#       '"Evidence for Mating of the Asexual Yeast Candida albicans in a '
#       'Mammalian Host"',
#       '"Reversal of Antipsychotic-Induced Working Memory Deficits by '
#       'Short-Term Dopamine D1 Receptor Stimulation"',
#       '"NMDA Receptor: Dependent Synaptic Reinforcement as a Crucial Process '
#       'for Memory Consolidation"']}

# %%
top_words2 = {}
for i in range(len(top_ten_words2)):
    one_doc_words = []
    for doc in top_ten_words2[i]:
        one_doc_words.append(words[doc])
    top_words2[i] = one_doc_words
pprint.pprint(top_words2)
# Out:
# {0: ['background',
#      'origin',
#      'units',
#      'dark',
#      'images',
#      'separate',
#      'flow',
#      'clearly',
#      'white',
#      'rapidly'],
#  1: ['late',
#      'events',
#      'age',
#      'rates',
#      'global',
#      'areas',
#      'source',
#      'water',
#      'period',
#      'area'],
#  2: ['london',
#      'online',
#      'germany',
#      'division',
#      'august',
#      'web',
#      'weight',
#      'tion',
#      'authors',
#      'report'],
#  3: ['mutants',
#      'mutation',
#      'mutations',
#      'mutant',
#      'genetic',
#      'wild',
#      'genes',
#      'dna',
#      'type',
#      'gene'],
#  4: ['experiments',
#      'proteins',
#      'molecular',
#      'function',
#      'specific',
#      'analysis',
#      'control',
#      'protein',
#      'cell',
#      'cells'],
#  5: ['change',
#      'possible',
#      'lower',
#      'state',
#      'high',
#      'small',
#      'large',
#      'low',
#      'system',
#      'surface'],
#  6: ['indicate'],
#  7: ['email',
#      'correspondence',
#      'addressed',
#      'reports',
#      'shown',
#      'observed',
#      'fig'],
#  8: ['phase'],
#  9: ['group',
#      'university',
#      'work',
#      'center',
#      'early',
#      'institute',
#      'like',
#      'see',
#      'new',
#      'research'],
#  10: ['year', 'years'],
#  11: ['identify',
#       'genome',
#       'contain',
#       'nuclear',
#       'cycle',
#       'amount',
#       'sequences',
#       'biology',
#       'edu',
#       'usa'],
#  12: ['mean',
#       'times',
#       'increased',
#       'effects',
#       'right',
#       'response',
#       'increase',
#       'effect',
#       'changes',
#       'time'],
#  13: ['san',
#       'individuals',
#       'efficient',
#       'plants',
#       'panel',
#       'causes',
#       'school',
#       'studied',
#       'groups',
#       'department'],
#  14: ['readers', 'card', 'circle', 'service', 'compass', 'mail', 'sciences'],
#  15: ['major',
#       'provide',
#       'recent',
#       'potential',
#       'first',
#       'important',
#       'based',
#       'study',
#       'studies',
#       'long'],
#  16: ['ability',
#       'numbers',
#       'critical',
#       'day',
#       'involved',
#       'growth',
#       'factors',
#       'normal',
#       'development',
#       'human'],
#  17: ['made'],
#  18: ['present',
#       'three',
#       'structure',
#       'found',
#       'show',
#       'single',
#       'data',
#       'region',
#       'number',
#       'model'],
#  19: ['test']}

# %%
# clustering documents might be useful for keyword extraction for a new paper
# clustering terms might be useful for finding related papers in the already seen pool

# clustering words is easier for humans without domain knowledge to make sense out of and validate the clusters
# i am able to imagine how the words in the same cluster are related, but cannot do the same for all the titles
# for example, for word cluster #3 it is very clear those words share a higher similarity, thus they are highly related 
# and should be clustered to the same cluster
