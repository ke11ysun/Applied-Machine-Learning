# %% [markdown]
# ### Load data

# %%
import numpy as np

with open('./sentiment_labelled_sentences/imdb_labelled.txt', 'r') as f:
    lines = f.readlines()
    imdb_pos_comments = []
    imdb_neg_comments = []
    for i in range(len(lines)):
        split = lines[i].split("\t")
        label = int(split[1])
        if label == 0:
            imdb_neg_comments.append(split[0])
        else:
            imdb_pos_comments.append(split[0])

print(len(imdb_pos_comments), len(imdb_neg_comments))
# Out:
# 500 500

# %%
with open('./sentiment_labelled_sentences/amazon_cells_labelled.txt', 'r') as f:
    lines = f.readlines()
    amazon_pos_comments = []
    amazon_neg_comments = []
    for i in range(len(lines)):
        split = lines[i].split("\t")
        label = int(split[1])
        if label == 0:
            amazon_neg_comments.append(split[0])
        else:
            amazon_pos_comments.append(split[0])

print(len(amazon_pos_comments), len(amazon_neg_comments))
# Out:
# 500 500

# %%
with open('./sentiment_labelled_sentences/yelp_labelled.txt', 'r') as f:
    lines = f.readlines()
    yelp_pos_comments = []
    yelp_neg_comments = []
    for i in range(len(lines)):
        split = lines[i].split("\t")
        label = int(split[1])
        if label == 0:
            yelp_neg_comments.append(split[0])
        else:
            yelp_pos_comments.append(split[0])

print(len(yelp_pos_comments), len(yelp_neg_comments))
# Out:
# 500 500

# %% [markdown]
# ### Preprocessing for training and testing data

# %%
# pool
train_pos_comments = imdb_pos_comments[:400] + amazon_pos_comments[:400] + yelp_pos_comments[:400]
test_pos_comments = imdb_pos_comments[400:] + amazon_pos_comments[400:] + yelp_pos_comments[400:]
train_neg_comments = imdb_neg_comments[:400] + amazon_neg_comments[:400] + yelp_neg_comments[:400]
test_neg_comments = imdb_neg_comments[400:] + amazon_neg_comments[400:] + yelp_neg_comments[400:]

comments = [train_pos_comments, test_pos_comments, train_neg_comments, test_neg_comments]
print([len(comments[i]) for i in range(len(comments))])
# Out:
# [1200, 300, 1200, 300]

# %%
# strip punctuation
# to lowercase

import pprint
import string, re
regex = re.compile('[%s]' % re.escape(string.punctuation))
comments = [[regex.sub('', comment.lower()) for comment in comment_group] for comment_group in comments]
pprint.pprint(comments[0][:10])
# Out:
# ['the best scene in the movie was when gerardo is trying to find a song that '
#  'keeps running through his head  ',
#  'saw the movie today and thought it was a good effort good messages for '
#  'kids  ',
#  'loved the casting of jimmy buffet as the science teacher  ',
#  'and those baby owls were adorable  ',
#  'the movie showed a lot of florida at its best made it look very appealing  ',
#  'the songs were the best and the muppets were so hilarious  ',
#  'it was so cool  ',
#  'this is a very right on case movie that delivers everything almost right in '
#  'your face  ',
#  'this review is long overdue since i consider a tale of two sisters to be the '
#  'single greatest film ever made  ',
#  'ill put this gem up against any movie in terms of screenplay cinematography '
#  'acting postproduction editing directing or any other aspect of filmmaking  ']

# %%
# lemmatization

from nltk.stem.wordnet import WordNetLemmatizer
from nltk import word_tokenize

lmtzr = WordNetLemmatizer()
lemmatized = [[[lmtzr.lemmatize(word, "v") for word in word_tokenize(s)]
              for s in comment_group] for comment_group in comments]
pprint.pprint(lemmatized[0][:10])

# lemmatizer not removing -ing because it assumes the word to be a noun.
# "s" in "was" was removed becasue it assumes it to be plural form.
# if we treat every word as verb, the "s" will also be removed because it will be considered as third person singular.
# Out:
# [['the',
#   'best',
#   'scene',
#   'in',
#   'the',
#   'movie',
#   'be',
#   'when',
#   'gerardo',
#   'be',
#   'try',
#   'to',
#   'find',
#   'a',
#   'song',
#   'that',
#   'keep',
#   'run',
#   'through',
#   'his',
#   'head'],
#  ['saw',
#   'the',
#   'movie',
#   'today',
#   'and',
#   'think',
#   'it',
#   'be',
#   'a',
#   'good',
#   'effort',
#   'good',
#   'message',
#   'for',
#   'kid'],
#  ['love',
#   'the',
#   'cast',
#   'of',
#   'jimmy',
#   'buffet',
#   'as',
#   'the',
#   'science',
#   'teacher'],
#  ['and', 'those', 'baby', 'owls', 'be', 'adorable'],
#  ['the',
#   'movie',
#   'show',
#   'a',
#   'lot',
#   'of',
#   'florida',
#   'at',
#   'its',
#   'best',
#   'make',
#   'it',
#   'look',
#   'very',
#   'appeal'],
#  ['the',
#   'songs',
#   'be',
#   'the',
#   'best',
#   'and',
#   'the',
#   'muppets',
#   'be',
#   'so',
#   'hilarious'],
#  ['it', 'be', 'so', 'cool'],
#  ['this',
#   'be',
#   'a',
#   'very',
#   'right',
#   'on',
#   'case',
#   'movie',
#   'that',
#   'deliver',
#   'everything',
#   'almost',
#   'right',
#   'in',
#   'your',
#   'face'],
#  ['this',
#   'review',
#   'be',
#   'long',
#   'overdue',
#   'since',
#   'i',
#   'consider',
#   'a',
#   'tale',
#   'of',
#   'two',
#   'sisters',
#   'to',
#   'be',
#   'the',
#   'single',
#   'greatest',
#   'film',
#   'ever',
#   'make'],
#  ['ill',
#   'put',
#   'this',
#   'gem',
#   'up',
#   'against',
#   'any',
#   'movie',
#   'in',
#   'term',
#   'of',
#   'screenplay',
#   'cinematography',
#   'act',
#   'postproduction',
#   'edit',
#   'direct',
#   'or',
#   'any',
#   'other',
#   'aspect',
#   'of',
#   'filmmaking']]

# %%
# eliminate duplicate
# modified the stopwords 

from nltk.corpus import stopwords

filtered = [[[word for word in set(word_list) if word not in stopwords.words('english_mod')] for word_list in comment_group] for comment_group in lemmatized]
pprint.pprint(filtered[:10])

# deleted stopwords: but, no, nor, not, don, don'tain, aren, aren't, couldn, couldn't, didn, didn't, doesn
# doesn't, hadn, hadn't, hasn, hasn't, haven, haven't, isn, isn't, ma, mightn, mightn't, mustn, mustn't, needn
# needn't, shan, shan't, shouldn, shouldn't, wasn, wasn't, weren, weren't, won, won't, wouldn, wouldn't
# Out:
# [[['best',
#    'gerardo',
#    'song',
#    'head',
#    'run',
#    'find',
#    'keep',
#    'movie',
#    'try',
#    'scene'],
#   ['today', 'message', 'think', 'effort', 'saw', 'kid', 'good', 'movie'],
#   ['science', 'jimmy', 'teacher', 'cast', 'buffet', 'love'],
#   ['baby', 'adorable', 'owls'],
#   ['lot', 'look', 'show', 'florida', 'appeal', 'make', 'movie', 'best'],
#   ['hilarious', 'songs', 'muppets', 'best'],
#   ['cool'],
#   ['deliver', 'almost', 'everything', 'right', 'face', 'movie', 'case'],
#   ['consider',
#    'long',
#    'single',
#    'ever',
#    'sisters',
#    'review',
#    'film',
#    'overdue',
#    'since',
#    'greatest',
#    'make',
#    'tale',
#    'two'],
#   ['screenplay',
#    'act',
#    'movie',
#    'cinematography',
#    'edit',
#    'term',
#    'put',
#    'ill',
#    'direct',
#    'postproduction',
#    'aspect',
#    'filmmaking',
#    'gem'],
#   ['masterpiece',
#    'true',
#    'masterpieces',
#    'perfect',
#    'faux',
#    'practically',
#    '\x96',
#    'sea'],
#   ['cinema', 'easily', 'tightly', 'construct', 'film', 'history', 'structure'],
#   ['occur',
#    'every',
#    'no',
#    'think',
#    'something',
#    'film',
#    'minute',
#    'important',
#    'vitally'],
#   ['enough', 'easily', 'fill', 'word', 'film', 'content', 'level', 'dozen'],
#   ['ask', 'mind', 'anyone', 'right', 'anything', 'movie'],
#   ['imaginable', 'cinema', 'quite', 'simply', 'highest', 'superlative', 'form'],
#   ['puzzlesolving',
#    'create',
#    'yes',
#    'amount',
#    'piece',
#    'together',
#    'require',
#    'film',
#    'significant',
#    'beautiful',
#    'but',
#    'picture',
#    'rather',
#    'fit'],
#   ['th', 'number', 'game', 'one', 'series', 'best'],
#   ['strong', 'love', 'deserve'],
#   ['game', 'insane'],
#   ['level', 'character', 'unlockable', 'game', 'massive'],
#   ['money', 'waste', 'game'],
#   ['money', 'waste', 'properly', 'kind'],
#   ['time', 'graphics', 'good', 'actually'],
#   ['fun', 'canada', 'game', 'say', 'aye'],
#   ['rock', 'game'],
#   ['enjoy', 'buy', 'love', 'play'],
#   ['brilliance', 'pure'],
#   ['succeed', 'despite', 'obviously', 'meagre', 'perhaps', 'film', 'budget'],
#   ['glad',
#    'film',
#    'didnt',
#    'choice',
#    'go',
#    'im',
#    'lesser',
#    'certainly',
#    'would',
#    'obvious'],
#   ['addition',
#    'songs',
#    'french',
#    'screen',
#    'boast',
#    'ladies',
#    'cutest',
#    'write',
#    'cancan',
#    'also',
#    'one',
#    'lovely',
#    'ever',
#    'grace',
#    'lead'],
#   ['not', 'hard', 'headoverheels', 'love', 'girl', 'fall'],
#   ['line', 'performances', 'cast', 'excellent', 'story'],
#   ['totally', 'believable'],
#   ['utterly', 'convince', 'anne', 'heche'],
#   ['sober', 'portrayal', 'ho', 'gung', 'marine', 'sam', 'shepards'],
#   ['sit', 'tv', 'screen', 'rivet'],
#   ['give', '10', '9', 'one', 'resound'],
#   ['hanks', 'think', 'tom', 'good', 'actor'],
#   ['read', 'enjoy', 'little', 'book', 'children'],
#   ['great', 'things', 'generally'],
#   ['g', 'cross', 'suspense', 'line', 'pg', 'builders', 'good'],
#   ['noncliche',
#    'dialog',
#    'especially',
#    'movie',
#    'could',
#    'write',
#    'but',
#    'selections',
#    'parent',
#    'movies',
#    'choices',
#    'like',
#    'make',
#    'predict',
#    'verbatim',
#    'better'],
#   ['not',
#    'chill',
#    'give',
#    'great',
#    'gross',
#    'but',
#    'choice',
#    'thats',
#    'movie',
#    'want'],
#   ['great', 'alexander', 'film', 'nevsky'],
#   ['amaze', 'film', 'live', 'one', 'whoever', 'artist', 'important'],
#   ['ive', 'first', 'give', '10', 'years', 'movie'],
#   ['need', 'wordofmouth', 'movie', 'ever', 'promote'],
#   ['film', 'thoughtprovoking', 'interest', 'overall'],
#   ['relatively', 'time', 'plus', 'wellpaced', 'run', 'suit', 'short'],
#   ['look', 'give', 'one'],
#   ['10', 'give'],
#   ['well', 'superbly', 'write', 'lion', 'act', 'wind'],
#   ['true', 'classic'],
#   ['far',
#    'turn',
#    'blist',
#    'decent',
#    'film',
#    'go',
#    'pretty',
#    'actually',
#    'horrorsuspense'],
#   ['worth', 'definitely', 'check'],
#   ['manna',
#    'heaven',
#    'film',
#    'unpredictable',
#    'terrific',
#    'predictable',
#    'time'],
#   ['evaluate',
#    'often',
#    'character',
#    'touch',
#    'funny',
#    'live',
#    'scenes',
#    'go',
#    'occasionally'],
#   ['nostalgia', 'actors', 'veteran', 'cast', 'trip'],
#   ['nun',
#    'time',
#    'burtons',
#    'church',
#    'fun',
#    'portrayal',
#    'nuns',
#    'make',
#    'ursula',
#    'touch',
#    'funny'],
#   ['end',
#    'terrific',
#    'movie',
#    'rendition',
#    'shirley',
#    'try',
#    'look',
#    'uplift',
#    'musicincluding',
#    'one',
#    'tonight',
#    'give',
#    'jones',
#    'cast',
#    'good',
#    'way'],
#   ['think', 'dont', 'disappoint'],
#   ['house', 'really', 'thing', 'watch', 'scenery', 'worth', 'beautiful'],
#   ['term', 'write', 'bold', 'but', 'fresh'],
#   ['sister',
#    'real',
#    'act',
#    'could',
#    'idiotsavant',
#    'watch',
#    'write',
#    'help',
#    'maybe',
#    'play',
#    'well',
#    'joy',
#    'better',
#    'along'],
#   ['prelude', 'however', 'give', 'applause'],
#   ['really', 'like'],
#   ['director', 'great', 'film'],
#   ['car',
#    'afraid',
#    'end',
#    'somewhat',
#    'edge',
#    'make',
#    'go',
#    'movie',
#    'night',
#    'seat'],
#   ['music', 'really', 'nice', 'film'],
#   ['id', 'advise', 'see', 'anyone', 'go'],
#   ['brilliant'],
#   ['1010'],
#   ['much', 'like', 'movie', 'way'],
#   ['rock',
#    'social',
#    'no',
#    'outlets',
#    'must',
#    'world',
#    'physical',
#    'see',
#    'anyone',
#    'certainly'],
#   ['view', 'definitely', 'others', 'well', 'cult', 'share', 'worth', 'classic'],
#   ['anthony',
#    'treat',
#    'quinn',
#    'crazy',
#    'also',
#    'real',
#    'see',
#    'play',
#    'horse'],
#   ['enough',
#    'not',
#    'theres',
#    'women',
#    'movies',
#    'like',
#    'still',
#    'empowerment',
#    'one',
#    'movie'],
#   ['ms', 'excellent', 'performance'],
#   ['garbo',
#    'bat',
#    'netflix',
#    'seem',
#    'right',
#    'era',
#    'want',
#    'could',
#    'show',
#    'silent',
#    'but',
#    'work',
#    'see',
#    'carry',
#    'stock',
#    'doesnt',
#    'talents'],
#   ['renowned',
#    'marion',
#    'great',
#    'miss',
#    'frances',
#    'see',
#    'also',
#    'silent',
#    'sound',
#    'go',
#    'hasnt',
#    'step',
#    'screenwriter'],
#   ['youll', 'love'],
#   ['receive', 'quality', 'great', 'film', 'age', 'movie'],
#   ['incredible', 'wayne', 'job', 'young', 'industry', 'john', 'movie'],
#   ['presence', 'actors', 'screen', 'though', 'think', 'senior', 'shin', 'even'],
#   ['wayne', 'think', 'must', 'older', 'film', 'see', 'john'],
#   ['foxx', 'jamie', 'absolutely', 'ray', 'charles'],
#   ['genius', 'simply', 'performance'],
#   ['quaid',
#    'spacek',
#    'great',
#    'film',
#    'fire',
#    'daughter',
#    'ball',
#    'coal',
#    'miners'],
#   ['not',
#    'part',
#    'man',
#    'fact',
#    'remember',
#    'hard',
#    'act',
#    'ray',
#    'play',
#    'charles'],
#   ['legendary', 'charles', 'ray'],
#   ['life',
#    'film',
#    'ray',
#    'movie',
#    'excellent',
#    'beyond',
#    'charles',
#    'musician',
#    'material',
#    'go',
#    'provide',
#    'another',
#    'well',
#    'biographical'],
#   ['director', 'great', 'hitchcock'],
#   ['much',
#    'thriller',
#    'hitchcock',
#    'chase',
#    'perfect',
#    'pretty',
#    'movie',
#    'secondly'],
#   ['watch', 'first', '80s', 'movie', 'love'],
#   ['music', 'totally', 'dance', 'everything', 'fascinate'],
#   ['ever',
#    'great',
#    'film',
#    'greatest',
#    'make',
#    'one',
#    'good',
#    'might',
#    'intentions'],
#   ['existential',
#    'actors',
#    'theme',
#    'imagination',
#    'might',
#    'director',
#    'great',
#    'film',
#    'themeat',
#    'scenes',
#    'character',
#    'deeply',
#    'sense',
#    'worldweariness',
#    'significant',
#    'ought',
#    'one',
#    'undertone',
#    'aerial',
#    'master',
#    'thrill',
#    'fifties',
#    'least',
#    'care',
#    'wouldbe'],
#   ['yet', 'enjoy', 'watch'],
#   ['nice'],
#   ['funny'],
#   ['funny'],
#   ['whatever',
#    'superbly',
#    'cant',
#    'surface',
#    'craft',
#    'say',
#    'else',
#    'spoilers'],
#   ['cinematography',
#    'stun',
#    'not',
#    'simply',
#    'fx',
#    'stateoftheart',
#    'nothing',
#    'least',
#    'say'],
#   ['bite',
#    'parent',
#    'show',
#    'conceptually',
#    'fx',
#    'fan',
#    'andor',
#    'everybody',
#    'everything',
#    'offer',
#    'fantasy',
#    'kid',
#    'little'],
#   ['single',
#    'either',
#    'solid',
#    'sour',
#    'strike',
#    'actingwise',
#    'wasnt',
#    'cast',
#    'surprisingly',
#    'note'],
#   ['consider', 'job', 'well', 'things'],
#   ['thank', 'like', 'release', 'good', 'movie'],
#   ['felt',
#    'identify',
#    'even',
#    'less',
#    'no',
#    'best',
#    'movies',
#    'one',
#    'ever',
#    'mexican',
#    'matter',
#    'understand'],
#   ['incredible',
#    'belmondo',
#    'great',
#    'ventura',
#    'noircrimedrama',
#    'rank',
#    'performances',
#    'lino',
#    'highly'],
#   ['every',
#    'portrayals',
#    'tremendous',
#    'character',
#    'complex',
#    'give',
#    'hope',
#    'psychological',
#    'treachery',
#    'loyalty',
#    'attention',
#    'detail',
#    'love'],
#   ['drama', 'thriller', 'film', 'excellent'],
#   ['melville', 'best'],
#   ['incredible', 'simply', 'film', 'everything'],
#   ['take', 'journey', 'truly', 'soul', 'child', 'eye'],
#   ['flick',
#    'limitations',
#    'intense',
#    'indie',
#    'manage',
#    'transcend',
#    'continually',
#    'thriller',
#    'expectations',
#    'emerge',
#    'experience',
#    'black',
#    'completely',
#    'subvert',
#    'water'],
#   ['website',
#    'grip',
#    'location',
#    'real',
#    'swamp',
#    'indeed',
#    'crocs',
#    'crocdodile',
#    'performances',
#    'black',
#    'extremely',
#    'well',
#    'use',
#    'believe',
#    'fabulous',
#    'thats',
#    'water'],
#   ['thoroughly',
#    'eccleston',
#    'enjoy',
#    'christopher',
#    'take',
#    'tardis',
#    'series',
#    'continuation',
#    'control'],
#   ['lot', 'place', 'beautiful'],
#   ['amaze', 'best', 'trilogy', 'finale', 'time', 'possibly'],
#   ['amaze', 'never', 'cease', 'kieslowski'],
#   ['cinema', 'favourite', 'talented', 'history', 'one', 'directors'],
#   ['incredible',
#    'french',
#    'film',
#    'flag',
#    'shoot',
#    'work',
#    'colour',
#    'short',
#    'three',
#    'art',
#    'like',
#    'scene',
#    'every',
#    'nothing',
#    'use'],
#   ['three', 'visually', 'ive', 'movies', 'see', 'appeal', 'ever'],
#   ['three', 'connections', 'awesome', 'film', 'subtle'],
#   ['end',
#    'together',
#    'suffer',
#    'deal',
#    'survivors',
#    'film',
#    'solidify',
#    'character',
#    'young',
#    'watch',
#    'many',
#    'remain',
#    'judge',
#    'three',
#    'mention',
#    'happiness',
#    'spoiler',
#    'love',
#    'tv',
#    'valentine',
#    'ferry',
#    'man',
#    'old',
#    'disaster',
#    'years',
#    'huge'],
#   ['amaze',
#    'smile',
#    'end',
#    'think',
#    'great',
#    'film',
#    'couldnt',
#    'but',
#    'trilogy',
#    'better',
#    'face',
#    'way',
#    'wrap'],
#   ['everyone',
#    'movies',
#    'recommend',
#    'art',
#    'film',
#    'anythinga',
#    'work',
#    'love'],
#   ['trilogy', '10', 'movie'],
#   ['people', 'another', 'think', 'roths', 'pearl', 'find', 'one'],
#   ['stun', 'award', 'performance'],
#   ['francis',
#    'unfold',
#    'tell',
#    'room',
#    'character',
#    '25',
#    'leave',
#    'coppola',
#    'story',
#    'develop',
#    'really',
#    'gradually',
#    'eloquently',
#    'earlier',
#    'years',
#    'ford'],
#   ['contrast', 'location', 'wonderful', 'lie', 'story'],
#   ['nicolas', 'roeg', 'sublime', 'cast', 'film', 'wih', 'direct', 'beautiful'],
#   ['fun', 'funny', 'movie'],
#   ['entertain', 'angle', 'highly'],
#   ['memorable',
#    'outlandish',
#    'psychotic',
#    'nut',
#    'array',
#    'feature',
#    'but',
#    'lovable'],
#   ['get', 'enjoyment', 'around', 'see', 'run', 'game', 'play', 'dangerous'],
#   ['sweet', 'even', 'moments'],
#   ['telephone',
#    'really',
#    'nut',
#    'reactions',
#    'bitchy',
#    'boss',
#    'man',
#    'genuine',
#    'funny',
#    'truly',
#    'repair'],
#   ['character', 'well', 'film', 'tremendously', 'play'],
#   ['really', 'funny', 'find'],
#   ['smart', 'movie', 'actually'],
#   ['twist', 'end', 'brilliant'],
#   ['love'],
#   ['end', 'shed', 'tear', 'youll', 'perfect'],
#   ['like', 'see', 'movie', 'thrill'],
#   ['forget', 'never'],
#   ['not', 'cult', 'classic'],
#   ['really', 'show', 'watch', 'good'],
#   ['8', 'old', 'educational', 'years', '1', 'children'],
#   ['definitely', 'super', 'de', 'barney', 'duper'],
#   ['pretty', 'funny'],
#   ['cute', 'bop', 'babie'],
#   ['cool', 'kid'],
#   ['television', 'give', '10', 'plus', 'series', 'would', 'could'],
#   ['actors',
#    'think',
#    'character',
#    'showthese',
#    'bonus',
#    'actresses',
#    'real',
#    'smack',
#    'writers',
#    'best'],
#   ['tap', 'episodes', 'watch', 'must', 'find', 'say'],
#   ['give', '10', 'know'],
#   ['part',
#    'movie',
#    'latch',
#    'become',
#    'dont',
#    'but',
#    'familys',
#    'special',
#    'endear',
#    'know',
#    'exactly',
#    'memories'],
#   ['totally',
#    'movies',
#    'recommend',
#    'like',
#    'family',
#    'wholesome',
#    'absolutely',
#    'anyone',
#    'exactly',
#    'good',
#    'movie'],
#   ['get', 'hilarious', 'watch', 'four', 'absolutely', 'kid', 'things'],
#   ['show', 'sibling', 'movies', 'strong', 'bond', 'one', 'best'],
#   ['much', 'suspense', 'controversy', 'action', 'interest', 'less', 'unneeded'],
#   ['cinematography', 'solid', 'everything', 'act'],
#   ['worth', 'definitely', 'check'],
#   ['screen',
#    'versatile',
#    'damian',
#    'write',
#    'many',
#    'portray',
#    'talented',
#    'character',
#    'different',
#    'ways'],
#   ['edge', 'cut', 'movie'],
#   ['us',
#    'passion',
#    'let',
#    'audience',
#    'day',
#    'art',
#    'take',
#    'drive',
#    'please',
#    'genius',
#    'know',
#    'modern'],
#   ['angelina',
#    'sven',
#    'ole',
#    'thorsen',
#    'usual',
#    'act',
#    'movie',
#    'decent',
#    'get',
#    'elias',
#    'help',
#    'appear',
#    'cameo',
#    'hot',
#    'palance',
#    'budget',
#    'drago',
#    'make',
#    'play',
#    'koteasjack',
#    'nakedbilly',
#    'enjoyable',
#    'cool',
#    'roles',
#    'good'],
#   ['buy', 'awesome', 'ebay', 'movie'],
#   ['question',
#    'away',
#    'poler',
#    'ask',
#    'cutebut',
#    'story',
#    'fort',
#    'steele',
#    'love',
#    'really',
#    'bear',
#    'kinda',
#    'line',
#    'anyone'],
#   ['full',
#    'part',
#    'think',
#    'excerpt',
#    'wonderful',
#    'wonder',
#    'work',
#    'literally'],
#   ['effective',
#    'amazingstylized',
#    'set',
#    'especially',
#    'camera',
#    'work',
#    'design',
#    'beautiful'],
#   ['designer', 'exemplars', 'use', 'set', 'could'],
#   ['nature', 'man', 'art', 'stories', 'powerful', 'explorations'],
#   ['watch', 'learn', 'film', 'work', 'artist', 'want'],
#   ['politics',
#    'recommend',
#    'art',
#    'anyone',
#    'poetry',
#    'interest',
#    'theater',
#    'highly',
#    'history',
#    'movie',
#    'japanese'],
#   ['lion', 'wonderful', 'see', 'render', 'americas', 'age', 'wind', 'imperial'],
#   ['cast',
#    'terrific',
#    'teddy',
#    'edit',
#    'vivid',
#    'keith',
#    'story',
#    'value',
#    'underappreciated',
#    'composition',
#    'different',
#    'make',
#    'brian',
#    'history',
#    'play',
#    'bully',
#    'photography',
#    'faultless',
#    'production'],
#   ['identify',
#    'stick',
#    'tell',
#    'connerys',
#    'hay',
#    'member',
#    'sean',
#    'spiffy',
#    'roosevelts',
#    'character',
#    'wily',
#    'family',
#    'lion',
#    'lieutenant',
#    'bergens',
#    'largely',
#    'ruthless',
#    'kanalys',
#    'son',
#    'radiant',
#    'cando',
#    'big',
#    'one',
#    'eye',
#    'hustons',
#    'whether',
#    'every',
#    'though',
#    'noble',
#    'candace',
#    'steve',
#    'feisty',
#    'brigand',
#    'wind',
#    'heroine',
#    'john'],
#   ['high', 'adventure', 'best'],
#   ['robert',
#    'think',
#    'film',
#    'portray',
#    'never',
#    'real',
#    'war',
#    'someone',
#    'father',
#    'schizophrenic',
#    'second',
#    'but',
#    'although',
#    'murder',
#    'best',
#    'like',
#    'world',
#    'make',
#    'affect',
#    'worse',
#    'anyone',
#    'ryans',
#    'lifemy'],
#   ['get', 'apt', 'humour', 'day'],
#   ['type',
#    'robert',
#    'impress',
#    'saw',
#    'portray',
#    'individual',
#    'brother',
#    'imitation',
#    'mother',
#    'thiswhen',
#    'man',
#    'ryan',
#    'good'],
#   ['every',
#    'part',
#    'quite',
#    'nonlinear',
#    'thus',
#    'well',
#    'many',
#    'articulate',
#    'flashbacks',
#    'narration'],
#   ['cinematography',
#    'look',
#    'bellucci',
#    'monica',
#    'also',
#    'make',
#    'good',
#    'beautiful'],
#   ['todays',
#    'film',
#    'see',
#    'commentary',
#    'undoubtedly',
#    'good',
#    'worth',
#    'love'],
#   ['people', 'job', 'first', 'timers', 'think', 'film', 'make', 'excellent'],
#   ['popular', 'cinema', 'house', 'reactions', 'plenty', 'laugh', 'good'],
#   ['cinema', 'thats', 'felt', 'come', 'film', 'feelgood'],
#   ['northern', 'positive', 'represent', 'humour', 'community'],
#   ['rather', 'enjoy'],
#   ['like'],
#   ['create', 'really', 'though', 'unique', 'feel'],
#   ['job', 'script', 'schilling', 'vivian', 'excellent'],
#   ['today', 'garbage', 'theatres', 'world', '95', 'better'],
#   ['well', 'role', 'play'],
#   ['not', 'masculine', 'right', 'screamy', 'but'],
#   ['really', 'like', 'camera', 'movie'],
#   ['ready', 'script', 'cast', 'role', 'would'],
#   ['time',
#    '1980s',
#    'live',
#    'european',
#    'movie',
#    'throwback',
#    'nationalities',
#    'although',
#    'experience',
#    'interact',
#    'nice',
#    'abroad',
#    'different',
#    'slightly',
#    'circumstances',
#    'student'],
#   ['adorablehis',
#    'part',
#    'totally',
#    'never',
#    'lid',
#    'feel',
#    'beforei',
#    'movie',
#    'little',
#    'sing',
#    'edition',
#    'funniest',
#    'whenscamp',
#    'scaredand',
#    'june',
#    'catch',
#    'movieits',
#    'excellentangel',
#    'yelp',
#    'ive',
#    'recommend',
#    'angel',
#    'special',
#    'beautiful',
#    'hes',
#    'garbage',
#    'scamp',
#    'curtain',
#    'come',
#    '20the',
#    'underneath',
#    'cover'],
#   ['itbuy',
#    'scenes',
#    'movie',
#    'adorablethe',
#    'feature',
#    'specialtoo',
#    'dog',
#    'junkyard',
#    'new',
#    'romanticcharminghilariousand',
#    'explain',
#    'laughedkids',
#    'love',
#    'outit',
#    'something',
#    'cant',
#    'come',
#    'funny',
#    'funnyall'],
#   ['flick',
#    'always',
#    'together',
#    'rag',
#    'billy',
#    'nutbag',
#    'side',
#    'premise',
#    'stephen',
#    'interest',
#    'dangerous',
#    'id',
#    'cheekbones',
#    'lance',
#    'drago',
#    'talk',
#    'mchattie',
#    'see',
#    'note',
#    'love',
#    'hendrikson',
#    'good'],
#   ['terrible', 'either', 'wasnt', 'soundtrack'],
#   ['get', '10', 'set', 'still', 'big', 'scale', 'oyvey'],
#   ['quite', 'job', 'amuse', 'good'],
#   ['minutes', 'not', 'last', 'bad', 'well', '15', 'also', 'movie'],
#   ['company',
#    'armand',
#    'assante',
#    'watch',
#    'like',
#    'summary',
#    'probably',
#    'sound',
#    'interest',
#    'cable',
#    'already',
#    'twice'],
#   ['tie', 'job', 'end', 'loose', 'believe', 'good', 'screenwriter'],
#   ['mostly', 'plot', '810', 'score'],
#   ['wont',
#    'time',
#    'like',
#    'film',
#    'worth',
#    'believe',
#    'dont',
#    'say',
#    'one',
#    'spoilers',
#    'but',
#    'want'],
#   ['deeply', 'character', 'impress', 'play'],
#   ['saw', 'great', 'film', 'come', 'gift', 'know', 'things', 'actor'],
#   ['end',
#    'great',
#    'movie',
#    'family',
#    'but',
#    'portrayal',
#    'special',
#    'love',
#    'know',
#    'share'],
#   ['star',
#    'ago',
#    'many',
#    'but',
#    'best',
#    'smith',
#    'movies',
#    '12',
#    'see',
#    'one',
#    'god',
#    'though',
#    'jaclyn',
#    'come',
#    'years'],
#   ['contain',
#    'havent',
#    'actors',
#    'allstar',
#    'movie',
#    'open',
#    'see',
#    'eye',
#    'love',
#    'cast'],
#   ['every', 'long', 'enjoy', 'kind', 'minute', 'length', 'but', 'movie'],
#   ['rate', '10', '110', 'overall', 'movie', 'scale'],
#   ['lifetime',
#    'not',
#    'enough',
#    'let',
#    'sell',
#    'musthave',
#    'anyone',
#    'know',
#    'store',
#    'air'],
#   ['totally',
#    'film',
#    'understatement',
#    'get',
#    'but',
#    'load',
#    'see',
#    'different',
#    'comedy',
#    'black',
#    'remember'],
#   ['every', 'create', 'universe', 'fascinate', 'movie', 'way'],
#   ['get', 'really', 'but', 'movie'],
#   ['see'],
#   ['movie',
#    'style',
#    'weird',
#    'hope',
#    'continue',
#    'team',
#    'movies',
#    'behind',
#    'make',
#    'really',
#    'kinda'],
#   ['superb',
#    'forget',
#    'aurvåg',
#    'bothersome',
#    'perfect',
#    'role',
#    'fausa',
#    'trond',
#    'doesnt',
#    'man',
#    'cast',
#    'understand'],
#   ['life', '2006', 'humorous', 'comment', 'good', 'movie'],
#   ['enjoyable', 'uplift', 'find', 'move', 'beautiful'],
#   ['sit', 'local', 'film', 'intrigue', 'initially', 'buffalo'],
#   ['lose', 'later', 'power', 'film', 'find'],
#   ['audience', 'applaud', 'film', 'entire', 'conclusion'],
#   ['race', 'joy', 'hope', 'leave', 'lilt', 'heart', 'theater', 'step', 'human'],
#   ['appearance', 'give', 'wholesome', 'duris', 'fine', 'performance'],
#   ['rest', 'well', 'also', 'cast', 'play'],
#   ['cinematography',
#    'noteworthy',
#    'view',
#    'include',
#    'barcelona',
#    'famed',
#    'gaudi',
#    'tower',
#    'fine'],
#   ['cast', 'good'],
#   ['check', 'worth'],
#   ['cast', 'great'],
#   ['deliver',
#    'really',
#    'middleaged',
#    'white',
#    'class',
#    'steve',
#    'funny',
#    'guy',
#    'uptight',
#    'upper',
#    'martin',
#    'performance'],
#   ['part',
#    'really',
#    'white',
#    'jean',
#    'everyone',
#    'well',
#    'great',
#    'cast',
#    'add',
#    'smart',
#    'play',
#    'betty'],
#   ['cinema',
#    'steamboat',
#    'willie',
#    'film',
#    'history',
#    'important',
#    'amazingly'],
#   ['appearance',
#    'year',
#    'crazy',
#    'plane',
#    'silent',
#    'second',
#    'groundbreaking',
#    'filmmostly',
#    'mickey',
#    'mouse',
#    'earlier',
#    'follow',
#    'famous',
#    'probably'],
#   ['tons',
#    'music',
#    'effect',
#    'sound',
#    'dont',
#    'but',
#    '1928',
#    'filmsomething',
#    'grant',
#    'pleaser',
#    'take',
#    'throughout',
#    'yet',
#    'mickey',
#    'speak',
#    'crowd',
#    'huge',
#    'hear'],
#   ['amaze',
#    'timeless',
#    'however',
#    'film',
#    '25',
#    'see',
#    'years',
#    'actually',
#    'short'],
#   ['imaginative',
#    'straw',
#    'mickey',
#    'occasionally',
#    'adorable',
#    'see',
#    'cruel',
#    'highly',
#    'turkey',
#    'way',
#    'play'],
#   ['even',
#    '80',
#    'mickeys',
#    'crowdpleaserthis',
#    'film',
#    'wonderful',
#    'still',
#    'real',
#    'rank',
#    'among',
#    'years',
#    'clever',
#    'best'],
#   ['body', 'masterpiece', '1947', 'original', 'soul'],
#   ['howe',
#    'ann',
#    'film',
#    'garfield',
#    'conrad',
#    'revere',
#    'canada',
#    'cinematographers',
#    'screenjames',
#    'plmer',
#    'one',
#    'wong',
#    'ever',
#    'grace',
#    'lilli',
#    'leeand',
#    'greatest',
#    'william',
#    'john'],
#   ['critic',
#    'fair',
#    'okay',
#    'pretty',
#    'credit',
#    'creature',
#    'ill',
#    'effect',
#    'duethe',
#    'like',
#    'consider',
#    'cool',
#    'give',
#    'actually'],
#   ['teeth', 'get', 'slimy', 'drool', 'closeups', 'love', 'ta'],
#   ['film',
#    'recent',
#    'almost',
#    'amount',
#    'weight',
#    'jonah',
#    'unrecognizable',
#    'spot',
#    'bright',
#    'interim',
#    'hill',
#    'look',
#    'fan',
#    'sole',
#    'lose',
#    'due',
#    'superbad'],
#   ['proudly',
#    'time',
#    'truly',
#    'even',
#    'classical',
#    '90s',
#    'show',
#    'say',
#    'cartoon',
#    'child',
#    'enjoy',
#    'wb',
#    'big'],
#   ['popular',
#    '90s',
#    'deliver',
#    'create',
#    'vibe',
#    'toons',
#    'funny',
#    'but',
#    'one',
#    'tiny',
#    'underrate',
#    'keep',
#    'ever',
#    'cartoon'],
#   ['every',
#    'episode',
#    'single',
#    'relate',
#    'show',
#    'enjoy',
#    'product',
#    'but',
#    'murky',
#    'say',
#    'memories'],
#   ['tender',
#    'get',
#    'teenagers',
#    'easily',
#    'none',
#    'dark',
#    'orient',
#    'laugh',
#    'make',
#    'sitcoms',
#    'way',
#    'cartoon'],
#   ['not', 'lead', 'true', 'character', 'funny', 'peculiarity'],
#   ['every', 'call', 'lead', 'hilarious', 'single', 'character', 'deserve'],
#   ['perabo',
#    'comfortable',
#    'obviously',
#    'front',
#    'nice',
#    'energy',
#    'camera',
#    'level'],
#   ['well', 'pitch', 'believe', 'black'],
#   ['people',
#    'think',
#    'find',
#    'movie',
#    'want',
#    'character',
#    'interest',
#    'go',
#    'longer',
#    'make',
#    'doesnt',
#    'surprise'],
#   ['watch', 'go'],
#   ['funny'],
#   ['really', 'character', 'care', 'interest'],
#   ['catchy',
#    'end',
#    'song',
#    'great',
#    'instant',
#    'soundtrack',
#    'credit',
#    'classic'],
#   ['miss', 'dont'],
#   ['retreat',
#    'study',
#    'wartime',
#    'theme',
#    'jealousy',
#    'piece',
#    'concern',
#    'cowardice',
#    'selfsacrifice',
#    'selfindulgent',
#    'span',
#    'lust',
#    'boil',
#    'warts',
#    'many',
#    'dedication',
#    'simmer',
#    'coastal',
#    'london',
#    'rivalry',
#    'bombardments',
#    'outward',
#    'heroism',
#    'experience',
#    'bohemian',
#    'masterful',
#    'art',
#    'poets',
#    'occasionally',
#    'filmmaking',
#    'friendship',
#    'aerial',
#    'love',
#    'egotism',
#    'welsh',
#    'practical',
#    'years',
#    'versus',
#    'tranquillity',
#    'borderlines'],
#   ['smile',
#    'often',
#    'script',
#    'time',
#    'bring',
#    'prone',
#    'suggest',
#    'tensions',
#    'character',
#    'direction',
#    'inappropriate',
#    'perfect',
#    'odd',
#    'knightley',
#    'mention',
#    'mature',
#    'focus',
#    'serve',
#    'performances',
#    'keira',
#    'subtle',
#    'occasionally',
#    'underlie',
#    'though',
#    'well',
#    'perhaps',
#    'apart',
#    'dramatic'],
#   ['wonder',
#    'camera',
#    'movie',
#    'angle',
#    'include',
#    'closeup',
#    'home',
#    'but',
#    'faux',
#    'visual',
#    'inventive',
#    'composition',
#    'exquisite',
#    'light',
#    'footage',
#    'behold',
#    'joy',
#    'use',
#    'pointillistic',
#    'elegant',
#    'moment'],
#   ['bertolucci',
#    'convince',
#    'continuously',
#    'engage',
#    'but',
#    'work',
#    'look',
#    'relationships',
#    'master',
#    'beautiful',
#    'narrative'],
#   ['saw', 'film', 'christmas', 'great'],
#   ['custer',
#    'think',
#    'become',
#    'favourite',
#    'actor',
#    'since',
#    'brilliant',
#    'errol',
#    'flynn'],
#   ['havilland',
#    'olivia',
#    'end',
#    'de',
#    'alongside',
#    'act',
#    'fantastic',
#    'brilliant'],
#   ['always',
#    'dads',
#    'film',
#    'brilliant',
#    'watch',
#    'actor',
#    'errol',
#    'flynn',
#    'child',
#    'favourite',
#    'know',
#    'grow'],
#   ['watch', 'great', 'film', 'wasnt', 'realise', 'but', 'actually'],
#   ['give', '10', 'film', 'ill'],
#   ['lot',
#    'plot',
#    'shenanigans',
#    'church',
#    'little',
#    'spy',
#    'surround',
#    'thriller',
#    'hitchcock',
#    'murder',
#    'foreign',
#    'nice',
#    'random',
#    'kidnap',
#    'child',
#    'lovely',
#    'taxidermists',
#    'nasty'],
#   ['great',
#    'hero',
#    'hitchcock',
#    'jimmy',
#    'hitchcocks',
#    'embassy',
#    'but',
#    'story',
#    'stewart',
#    'function',
#    'climax',
#    'black',
#    'rip',
#    'ever',
#    'cool',
#    'white',
#    'menace',
#    'lowbudget',
#    'original',
#    'lack',
#    'along',
#    'brood'],
#   ['another',
#    'stable',
#    'yet',
#    'great',
#    'film',
#    'wonderful',
#    'nevertheless',
#    'master'],
#   ['produce',
#    'excellently',
#    'typical',
#    'rat',
#    'film',
#    'sci',
#    'fi',
#    'say',
#    'top'],
#   ['produce',
#    'excellently',
#    'scifis',
#    'producers',
#    'one',
#    'scot',
#    'vandiver',
#    'best'],
#   ['entertain', 'but', 'nonetheless'],
#   ['watch', 'joy', 'sort', 'campy', 'film', 'thats'],
#   ['part', 'theres', 'barely', 'film', 'bore', 'plenty', 'humorous', 'moment'],
#   ['entertain', 'always', 'usual', 'cast'],
#   ['overall', 'delight'],
#   ['incredible',
#    'reveal',
#    'job',
#    'task',
#    'africa',
#    'complexity',
#    'challenge',
#    'face',
#    'movie',
#    'excellent',
#    'south'],
#   ['people',
#    'truth',
#    'think',
#    'movie',
#    'process',
#    'outside',
#    'south',
#    'attempt',
#    'see',
#    'one',
#    'africa',
#    'every',
#    'past',
#    'believe',
#    'reconciliation',
#    'understand'],
#   ['magnificent', 'photographycinematography', 'nothing', 'film', 'short'],
#   ['weave',
#    'view',
#    'dog',
#    'together',
#    'stories',
#    'must',
#    'rent',
#    'see',
#    'act',
#    'fantastic',
#    'seamlessly',
#    'splendid'],
#   ['afraid',
#    'aversion',
#    'dont',
#    '1010',
#    'therapy',
#    'worth',
#    'little',
#    'subtitle'],
#   ['excellent', 'performance'],
#   ['actors', 'around', 'still', 'good'],
#   ['photography', 'great', 'also', 'direct'],
#   ['true', 'must', 'fan', 'shakespear'],
#   ['decay',
#    'dark',
#    'connery',
#    'force',
#    'brief',
#    'final',
#    'tear',
#    'candle',
#    'interest',
#    'sphere',
#    'outhe',
#    'monolog',
#    'moral',
#    'make',
#    'macbeth',
#    'jason',
#    'give',
#    'face',
#    'move',
#    'human'],
#   ['evil',
#    'time',
#    'baxendale',
#    'cheerfull',
#    'taste',
#    'lady',
#    'helen',
#    'naughty',
#    'but',
#    'girl',
#    'credible',
#    'deadly',
#    'look',
#    'sometimes',
#    'like',
#    'blood',
#    'macbeth'],
#   ['shakespears', 'lyric', 'decay', 'one', 'love', 'death'],
#   ['upas',
#    'book',
#    'deserve',
#    'award',
#    'witty',
#    'dr',
#    'finest',
#    'animate',
#    'seuss',
#    'academy',
#    'delightful',
#    'thoroughly',
#    'adaptation',
#    'brilliantly'],
#   ['superb',
#    'memorable',
#    'element',
#    'integral',
#    'music',
#    'help',
#    'effect',
#    'sound',
#    'score',
#    'cartoon',
#    'mention',
#    'special',
#    'make',
#    'enjoyable'],
#   ['superb',
#    'however',
#    'film',
#    'complex',
#    'make',
#    'indeed',
#    'schrader',
#    'paul',
#    'mishima'],
#   ['memorable',
#    'color',
#    'costume',
#    'ishioka',
#    'crisp',
#    'receive',
#    'great',
#    'deserve',
#    'cinematography',
#    'go',
#    'design',
#    'eiko',
#    'baileys',
#    'also',
#    'coppolas',
#    'notable',
#    'fine',
#    'well',
#    'dracula',
#    'beautifully',
#    'john',
#    'production',
#    'oscar'],
#   ['sisters',
#    'watch',
#    'however',
#    'actresses',
#    'consolations',
#    'job',
#    'wonderful',
#    'annes',
#    'play',
#    'small',
#    'roles'],
#   ['stun', 'movie'],
#   ['move', 'raw', 'sublimely'],
#   ['people',
#    'grip',
#    'intelligent',
#    'without',
#    'felt',
#    'theatrical',
#    'feel',
#    'get',
#    'stage',
#    'escalate',
#    'watch',
#    'consequences',
#    'but',
#    'monstrous',
#    'terror',
#    'like',
#    'overly',
#    'one',
#    'play',
#    'white',
#    'everyones',
#    'lie',
#    'actually'],
#   ['players', 'mesmerise', 'main'],
#   ['end',
#    'alike',
#    'amount',
#    'everyone',
#    'break',
#    'go',
#    'judge',
#    'hand',
#    'wilkinson',
#    'fumble',
#    'elses',
#    'males',
#    'tom',
#    'heart',
#    'hankies',
#    'among',
#    'females',
#    'face'],
#   ['fellowes', 'julian', 'triumph'],
#   ['hes', 'national', 'treasure'],
#   ['see', 'go'],
#   ['film', 'excellent'],
#   ['scenes', 'welldone', 'aerial'],
#   ['also', 'right', 'war', 'love', 'balance'],
#   ['much',
#    'mean',
#    'owe',
#    'give',
#    'conflict',
#    'film',
#    'never',
#    'many',
#    'history',
#    'human',
#    'phrase'],
#   ['really', 'movie', 'difference', 'kristoffersen', 'make', 'good', 'kris'],
#   ['director', 'great', 'film', 'good'],
#   ['look',
#    'definitely',
#    'relationships',
#    'family',
#    'documentaries',
#    'see',
#    'better',
#    'one',
#    'marriage'],
#   ['great', 'movie'],
#   ['star', '10'],
#   ['cinema', 'punishment', 'park', 'piece', 'brilliant'],
#   ['style',
#    'create',
#    'desert',
#    'no',
#    'watkins',
#    'shoot',
#    'use',
#    'documentary',
#    'film',
#    'like',
#    'california',
#    'faux',
#    'southern',
#    'patent'],
#   ['peter', 'watkins', 'film', 'one', 'accessible'],
#   ['look', 'advise'],
#   ['wont', 'regret'],
#   ['recommend', 'highly'],
#   ['morgan',
#    'stanwyck',
#    'carol',
#    'equivalent',
#    'many',
#    'christmas',
#    'sensibility',
#    'dickens',
#    'cast',
#    'perfectly',
#    'modern',
#    'ways'],
#   ['depend',
#    'yardley',
#    'success',
#    'character',
#    'alexander',
#    'film',
#    'greenstreet',
#    'cast',
#    'sydney'],
#   ['gem', 'film', 'set', 'use', 'eyepleasing', 'throughout', 'attractive'],
#   ['transfer', 'good'],
#   ['view', 'nice', 'relax', 'late', 'night'],
#   ['full', 'dance', 'title', 'hence', 'wonderful', 'movie'],
#   ['music', 'great', 'terrific', 'scenery'],
#   ['course',
#    'shock',
#    'handle',
#    'tough',
#    'issue',
#    'dignity',
#    'spoiler',
#    'grace'],
#   ['happy', 'end', 'wonderful', 'feel', 'good'],
#   ['every', 'point', 'touch', 'family', 'journey', 'member'],
#   ['memorize',
#    'whenever',
#    'tvnever',
#    'movies',
#    'fact',
#    'come',
#    'need',
#    'mind',
#    'see',
#    'one',
#    'already'],
#   ['saw', 'recommend', 'film'],
#   ['superb',
#    'plot',
#    'act',
#    'complete',
#    'watson',
#    'fantastic',
#    'hold',
#    'wilkinson',
#    'emily',
#    'also',
#    'attention',
#    'tom',
#    'good'],
#   ['indeed', 'unconditional', 'great', 'film', 'good', 'love'],
#   ['suffer',
#    'great',
#    'feel',
#    'prepare',
#    'wilkinsons',
#    'performance',
#    'anguish',
#    'character',
#    'but',
#    'progress',
#    'story',
#    'actor',
#    'hand',
#    'take',
#    'make',
#    'begin',
#    'not',
#    'man',
#    'ordeal',
#    'give',
#    'tom',
#    'matter'],
#   ['glance',
#    'character',
#    'emily',
#    'give',
#    'strong',
#    'watsons',
#    'quick',
#    'everything',
#    'understand'],
#   ['despite', 'like', 'reviewers', 'pan', 'movie'],
#   ['townsend',
#    'vampire',
#    'stuart',
#    'fact',
#    'like',
#    'attempt',
#    'interview',
#    'better',
#    'cruise',
#    'lestat'],
#   ['entrance',
#    'dance',
#    'first',
#    'akasha',
#    'compel',
#    'aailiyah',
#    'mini',
#    'pretty',
#    'good',
#    'place',
#    'scene'],
#   ['mostly',
#    'style',
#    'fan',
#    'anne',
#    'sensitivities',
#    'big',
#    'due',
#    'im',
#    'series',
#    'rice',
#    'treatments'],
#   ['like', 'believable', 'guess', 'dysfunctionhe', 'detail'],
#   ['think', 'act', 'skilled', 'but'],
#   ['meredith', 'right', 'better'],
#   ['charm', 'film', 'wonderful', 'heart', 'sentiment'],
#   ['time',
#    'tell',
#    'tale',
#    'rare',
#    'indulgent',
#    'fall',
#    'filmmaker',
#    'moral',
#    'trap',
#    'take',
#    'syrupy',
#    'worthy',
#    'overly',
#    'doesnt',
#    'love',
#    'care'],
#   ['nine', 'film', 'truly', 'lovely', 'ten'],
#   ['good',
#    'addition',
#    'subgenre',
#    'giallo',
#    'film',
#    'early',
#    'goremeister',
#    'future',
#    'lucio',
#    'fulci'],
#   ['italian', '70s', 'early', 'thrillers', 'one', 'best'],
#   ['scene', 'standout'],
#   ['ortolani',
#    'distant',
#    'film',
#    'act',
#    'vocal',
#    'impressive',
#    'effective',
#    'music',
#    'riz',
#    'technically',
#    'sound',
#    'hill',
#    'particularly',
#    'unaccompanied',
#    'like',
#    'recur',
#    'camerawork',
#    'make',
#    '\x96',
#    'female',
#    'well',
#    'solid',
#    'come',
#    'good'],
#   ['cinema',
#    'though',
#    'wild',
#    'giallo',
#    'recommend',
#    'fan',
#    'still',
#    'stuff',
#    'highly'],
#   ['end', 'interest', 'movie', 'begin'],
#   ['ready',
#    'stay',
#    'character',
#    'like',
#    'hoffmans',
#    'everything',
#    'son',
#    'dustin',
#    'way'],
#   ['reveal', 'also', 'movie'],
#   ['compromise',
#    'people',
#    'show',
#    'think',
#    'learn',
#    'without',
#    'issue',
#    'personally',
#    'find',
#    'self',
#    'involve'],
#   ['central',
#    'blow',
#    'ps',
#    'cool',
#    'character',
#    'find',
#    'room',
#    'movie',
#    'scene'],
#   ['effect', 'rather', 'subtle', 'fresh', 'sublime'],
#   ['call', 'small', 'reviewer', 'italian', 'great', 'film', 'right', 'thats'],
#   ['part',
#    'nervous',
#    'actors',
#    'events',
#    'change',
#    'especially',
#    'performance',
#    'jennifer',
#    'star',
#    'jamie',
#    'wonderful',
#    'rubin',
#    'begin',
#    'cool',
#    'strange',
#    'starlet',
#    'give',
#    'harris'],
#   ['lot', 'inside', 'emotions', 'people', 'learn', 'business', 'real', 'movie'],
#   ['situations', 'game', 'act', 'coach', 'fascinate', 'movie', 'play', 'begin'],
#   ['music',
#    'possibly',
#    'best',
#    'ive',
#    'also',
#    'hear',
#    'snow',
#    'score',
#    'ever',
#    'mark'],
#   ['wont', 'forget', 'movie'],
#   ['tv', 'stranger', 'saw', 'child', '1973', 'back', 'love'],
#   ['astronaut',
#    'war',
#    'movie',
#    'astronauts',
#    'biggest',
#    'doctor',
#    'ussr',
#    'duet',
#    'perfect',
#    'but',
#    'cold',
#    'make',
#    'one',
#    'begin',
#    'exchange',
#    'consider',
#    'well',
#    'fear',
#    'crash'],
#   ['awesome', 'movie'],
#   ['really', 'scary', 'love'],
#   ['way', 'horror', 'movies', 'scream', 'rank', 'one', 'love'],
#   ['rent', 'real', 'one', 'want', 'scare'],
#   ['1010'],
#   ['film', 'extraordinary'],
#   ['drama',
#    'compel',
#    'frighten',
#    'indictment',
#    'american',
#    'courtroom',
#    'justice',
#    'system'],
#   ['legal',
#    'film',
#    'discover',
#    'rather',
#    'fundamental',
#    'court',
#    'process',
#    'present',
#    'guilt',
#    'but',
#    'highlight',
#    'flaw',
#    'innocence',
#    'not',
#    'better'],
#   ['well',
#    'understate',
#    'ive',
#    'film',
#    'documentaries',
#    'see',
#    'one',
#    'courtroom',
#    'pace',
#    'best'],
#   ['mostly',
#    'tv',
#    'get',
#    'cole',
#    'boost',
#    'factbased',
#    'routine',
#    'drama',
#    'fine',
#    'performance'],
#   ['not', 'bad', 'watch', 'predictable', 'but'],
#   ['pull', 'part', 'range', 'ability', 'clear'],
#   ['well', 'carry', 'movie'],
#   ['underlie',
#    'motivations',
#    'give',
#    'constantine',
#    'everything',
#    'right',
#    'seem',
#    'psychological',
#    'good',
#    'intensity',
#    'understand'],
#   ['get', 'dvd', 'watch', 'wonderful', 'hope', 'release', 'video', 'inspire'],
#   ['edit', 'phenomenal', 'film', 'opinion'],
#   ['life',
#    'adams',
#    'subject',
#    'could',
#    'young',
#    'many',
#    'jay',
#    'emotions',
#    'talk',
#    'explain',
#    'evoke',
#    'play',
#    'man',
#    'song',
#    'unfortunate',
#    'old',
#    'neil',
#    'better'],
#   ['cinematography', 'shoot', 'film', 'interest', 'way'],
#   ['course', 'footage', '70s', 'film', 'grainy', 'but', 'enhance'],
#   ['many', 'film', 'surprise', 'delight', 'offer'],
#   ['layer',
#    'situation',
#    'film',
#    'perfectly',
#    'movie',
#    'sing',
#    'excellent',
#    'appreciate',
#    'duet',
#    'philippa',
#    'giovanni',
#    'subtle',
#    'achille',
#    'don',
#    'beautifully',
#    'describe'],
#   ['unfold',
#    'century',
#    'music',
#    'instrument',
#    'jutland',
#    'story',
#    '18th',
#    'one',
#    'play',
#    'fine',
#    'period',
#    'touch',
#    'use'],
#   ['cailles',
#    'partake',
#    'movie',
#    'even',
#    'sample',
#    'loewenhielms',
#    'savor',
#    'watch',
#    'but',
#    'sarcophage',
#    'en',
#    'exquisite',
#    'small',
#    'wish',
#    'though',
#    'general',
#    'joy',
#    'share'],
#   ['last', 'understate', 'film', 'leave', 'but', 'impression'],
#   ['contrast', 'generate', 'warmth', 'backdrop', 'austere'],
#   ['dance', 'star', 'leave', 'go', 'theater', 'want'],
#   ['youd', 'act', 'expect', 'top', 'cast', 'notch'],
#   ['actors',
#    'script',
#    'right',
#    'deadpan',
#    'surprisingly',
#    'amount',
#    'hilarious',
#    'character',
#    'tongue',
#    'sharply',
#    'cheek',
#    'blake',
#    'deliver',
#    'particularly',
#    'flesh',
#    'dialogue',
#    'make',
#    'grime',
#    'well',
#    'line',
#    'realistic'],
#   ['memorable',
#    'scrimm',
#    'somewhat',
#    'performance',
#    'doctor',
#    'brief',
#    'role',
#    'but',
#    'anatomist',
#    'turn',
#    'quinn',
#    'also',
#    'violinplaying',
#    'gently',
#    'menace',
#    'angus',
#    'good'],
#   ['good', 'excellent', 'value', 'case'],
#   ['great', 'jawbone'],
#   ['mic', 'great'],
#   ['razr', 'owneryou', 'must'],
#   ['quality', 'great', 'sound'],
#   ['original', 'battery', 'extend', 'go', 'impress'],
#   ['though', 'good', 'quality'],
#   ['phone', 'blue', 'recommend', 'one', 'highly', 'tooth'],
#   ['far', 'good'],
#   ['great', 'work'],
#   ['buy', 'kindle', 'fire', 'use', 'absolutely', 'love'],
#   ['three',
#    'yet',
#    'days',
#    'new',
#    'battery',
#    'bar',
#    'without',
#    'run',
#    'thats',
#    'two',
#    'charge'],
#   ['phone', 'pocket', 'combination', 'great', 'pc'],
#   ['phone', '7', 'ive', 'mobile', 'say', 'months', 'best'],
#   ['people', 'whose', 'like', 'sensitive', 'product', 'ears', 'ideal'],
#   ['include',
#    'charger',
#    'well',
#    'sure',
#    'recommend',
#    'never',
#    'run',
#    'ac',
#    'make',
#    'car',
#    'juicehighy'],
#   ['well', 'keep'],
#   ['great', 'work', '680', 'fine', 'case'],
#   ['pics',
#    'quality',
#    'great',
#    'nice',
#    'clear',
#    'camera',
#    '2mp',
#    'thats',
#    'picture'],
#   ['price', 'right', 'nice', 'headset'],
#   ['excellent', 'bluetooth', 'headset'],
#   ['feature', 'want'],
#   ['well', 'seem', 'make', 'case'],
#   ['phone', 'not', 'bulky', 'protection', 'make', 'good'],
#   ['neat',
#    'turn',
#    'gadget',
#    'usable',
#    'pda',
#    'machine',
#    'keyboard',
#    'instead',
#    'useful',
#    'realworld',
#    'actually'],
#   ['phone', 'sturdy', 'ive', 'large', 'never', 'problems', 'pretty'],
#   ['thing', 'love'],
#   ['reasonable', 'price', 'everything', 'ie', 'fine'],
#   ['phone',
#    'work',
#    'stream',
#    'great',
#    '15',
#    'still',
#    'second',
#    'drop',
#    'submerge',
#    'even'],
#   ['happy',
#    'end',
#    'complaints',
#    'no',
#    '510',
#    'sound',
#    'quality',
#    'one',
#    'regard'],
#   ['really',
#    'look',
#    'cool',
#    'faceplates',
#    'recommend',
#    'nice',
#    'since',
#    'elegant'],
#   ['think',
#    'great',
#    'find',
#    'seriously',
#    'best',
#    'purchase',
#    'last',
#    'ive',
#    'headphones',
#    'make',
#    'several',
#    'perhaps',
#    'years'],
#   ['get',
#    'wear',
#    'comfortable',
#    'headsets',
#    'sometimes',
#    'glass',
#    'feel',
#    'way'],
#   ['ipods', 'great'],
#   ['several', 'great', 'device', 'situations1'],
#   ['great', 'choice'],
#   ['nice', 'home', 'station', 'work', 'dock'],
#   ['phone', 'beautiful'],
#   ['product', 'love'],
#   ['item', 'great', 'little'],
#   ['phone', 'handy', 'lot', 'feature', 'love'],
#   ['hold', 'wear', 'well', 'everyday'],
#   ['arrive', 'intend', 'well', 'time', 'work', 'package'],
#   ['everyone', 'headsets', 'use', 'love', 'easy'],
#   ['phone', 'work', 'great'],
#   ['product',
#    'better',
#    'verizon',
#    'work',
#    'one',
#    'boy',
#    'excellent',
#    'cheaper'],
#   ['phone', 'load', 'super'],
#   ['make', 'sturdy'],
#   ['great', 'work'],
#   ['order'],
#   ['find',
#    'far',
#    '2',
#    'try',
#    'best',
#    'ease',
#    'quality',
#    'listener',
#    'ive',
#    'one',
#    'well',
#    'bluetooths',
#    'use'],
#   ['phone', 'razr', 'motorola', 'seamlessly', 'integrate'],
#   ['bargain', 'definitely'],
#   ['purchase', 'price', 'ship', 'free', 'good'],
#   ['style',
#    'cool',
#    'white',
#    'nice',
#    'like',
#    'also',
#    'picture',
#    'camera',
#    'prosgood',
#    'black'],
#   ['reception',
#    'headset',
#    'comfortable',
#    'bluetooth',
#    'great',
#    'ear',
#    'piece',
#    '350',
#    'good',
#    'jabra350',
#    'love',
#    'fit'],
#   ['2',
#    'call',
#    'headset',
#    'quality',
#    'end',
#    'ask',
#    'use',
#    'wife',
#    'sound',
#    'excellent'],
#   ['phone', 'slim', 'display', 'light', 'beautiful'],
#   ['leather',
#    'think',
#    'right',
#    'little',
#    'ooze',
#    'but',
#    'geeky',
#    'stylish',
#    'sleek',
#    'toast',
#    'rock',
#    'sex',
#    'battery',
#    'embed',
#    'thats',
#    'case'],
#   ['fast', 'product', 'great', 'ship'],
#   ['absolutely', 'great'],
#   ['full',
#    'phone',
#    'keypad',
#    'cell',
#    'nice',
#    'keyboard',
#    'number',
#    'qwerty',
#    'basic',
#    'compromise'],
#   ['comfortable', 'ear'],
#   ['us', 'winner'],
#   ['simpler', 'couldnt', 'setup'],
#   ['cell',
#    'ear',
#    'find',
#    'comfortably',
#    'first',
#    'try',
#    'ive',
#    'different',
#    'one',
#    'phone',
#    'several',
#    'jabra',
#    'earpieces',
#    'fit'],
#   ['purchase', 'iam', 'please'],
#   ['job', 'get'],
#   ['audio', 'great'],
#   ['really', 'ive', 'bluetooth', 'like', 'weeks', 'but'],
#   ['get', 'small', 'use', 'dont', 'even', 'realize'],
#   ['almost', 'software', 'accompany', 'brilliant'],
#   ['headset', 'nicely', 'great', 'avoid', 'work', 'damage', 'package'],
#   ['recommend', 'definitly'],
#   ['price', 'stuff', 'good'],
#   ['headset', 'peachykeen', 'work'],
#   ['voice', 'recognition', 'tremendous'],
#   ['phone', 'get', 'relative', 'glad', 'im', 'reccomendation'],
#   ['problem',
#    'blackberry',
#    'curve',
#    '8530',
#    'no',
#    'headset',
#    'link',
#    'absolutely'],
#   ['sketchy',
#    'great',
#    'like',
#    'technology',
#    'funny',
#    'wouldnt',
#    'seem',
#    'sound',
#    'know',
#    'but',
#    'work',
#    'wellwell',
#    'one'],
#   ['fast',
#    'previous',
#    'message',
#    'kind',
#    'faster',
#    'send',
#    'phone',
#    'browse',
#    'web',
#    'use',
#    'significantly'],
#   ['build', 'cheap', 'quality', 'nice', 'unlike'],
#   ['item', 'fantastic', 'work', 'perfectly'],
#   ['color', 'love'],
#   ['w810i', 'superb'],
#   ['great', 'charger'],
#   ['phone', 'get', 'charm', 'like', 'one', 'work'],
#   ['great', 'value'],
#   ['look', 'screen', 'nice', 'great', 'graphics', 'clear', 'sharp'],
#   ['service', 'excellent'],
#   ['chargers', 'really', 'igo', 'great', 'tip'],
#   ['options', 'needshandsfree', 'file', 'great', 'browser', 'offer', 'one'],
#   ['superb', 'phone', 'network', 'great'],
#   ['hs850',
#    'pocket',
#    'bluetoothmotorola',
#    'work',
#    'wifes',
#    'like',
#    'charm',
#    'whether',
#    'phone',
#    'connect',
#    'case'],
#   ['quality', 'awesome', 'sound', 'good', 'functionality'],
#   ['incredible'],
#   ['phone', 'great'],
#   ['phone', 'buy', 'ring', 'good', 'toneoverall'],
#   ['phone', 'extremely', 'nice', 'lately', 'helpful'],
#   ['weight', 'hardly', 'notice', 'light'],
#   ['youll', 'thin', 'love'],
#   ['color',
#    'incredibly',
#    'think',
#    'graphics',
#    'prettier',
#    'sharp',
#    'even',
#    'would'],
#   ['think', 'investment', 'good'],
#   ['fm', 'transmitters', 'electronics', 'available', 'best'],
#   ['headset', 'great', 'impress', 'h500'],
#   ['phone', 'part', 'reasonably', 'mega', '12', 'pixel', 'camera', 'good7'],
#   ['2', 'ive', 'great', 'nearly', 'years', 'work'],
#   ['good', 'audio', 'transmit'],
#   ['price', 'also', 'great'],
#   ['house',
#    'live',
#    'room',
#    'decent',
#    'no',
#    'receptionsound',
#    'roam',
#    'quality',
#    'ive',
#    'around',
#    'range',
#    'phone',
#    'able',
#    'issue'],
#   ['fast', 'service'],
#   ['recommend', 'highly', 'would'],
#   ['recommend', 'would'],
#   ['phone', 'infatuate', 'still', 'im'],
#   ['simple', 'lightweight', 'great', 'fit'],
#   ['comfortable', 'decent', 'certainly', 'functionality'],
#   ['headbands',
#    'lightweight',
#    'doesnt',
#    'usually',
#    'like',
#    'hair',
#    'dont',
#    'but',
#    'one',
#    'mess'],
#   ['service', 'sound', 'great'],
#   ['far', 'really', 'product', 'please'],
#   ['purchase', 'favorite', 'one', 'ever'],
#   ['market', 'bluetooth', 'best'],
#   ['authentic', 'leather', 'nice', 'recommend', 'shine', 'comfort', 'case'],
#   ['get', 'really', 'headset', 'think', 'cute', 'excite'],
#   ['every', 'worth', 'penny'],
#   ['type', 'phone', 'wallet', 'excellent', 'case'],
#   ['price', 'nice', 'great', 'headphones', 'work'],
#   ['wear',
#    'comfortable',
#    'well',
#    'use',
#    'probably',
#    'aspect',
#    'important',
#    'case'],
#   ['glove', 'durable', 'like', 'strong', 'secure', 'fit'],
#   ['phone', 'gosh', 'ever', 'best'],
#   ['quality', 'appear', 'good', 'attractive'],
#   ['feature', 'love', 'factor', 'form'],
#   ['earpiece', 'great'],
#   ['excellent', 'free', 'hand', 'tool'],
#   ['great', 'stereo', 'use', 'home'],
#   ['good', 'product', 'incredible', 'value'],
#   ['far', 'month', 'but', 'work', 'flawlessly'],
#   ['great', 'work'],
#   ['life', 'battery', 'real', 'good'],
#   ['item', 'great'],
#   ['love', 'headset'],
#   ['perfectly', 'work'],
#   ['star', 'quality', 'give', 'sound', '5'],
#   ['work', 'great', 'reversible', 'plug'],
#   ['phone', 'good'],
#   ['rotate', 'feature', 'helpful', 'best'],
#   ['whole', 'family', 'comfort'],
#   ['good', 'product', 'seller'],
#   ['bluetooth', 'love'],
#   ['headset', 'impress', 'plantronics'],
#   ['get', 'small', 'adorable'],
#   ['phone', 'great'],
#   ['every',
#    'overnite',
#    'item',
#    'no',
#    'let',
#    'instal',
#    'great',
#    'since',
#    'problems',
#    'work',
#    'good',
#    'charge'],
#   ['phone', 'great'],
#   ['phone', 'excellent'],
#   ['voice', 'recognition', 'handset', 'excellent', 'thru'],
#   ['phone', 'hand', 'ive', 'ever', 'best'],
#   ['phone',
#    'cat',
#    'screen',
#    'destroy',
#    'great',
#    'attack',
#    'scratch',
#    'work',
#    'instead',
#    'strip',
#    'protective'],
#   ['price', 'right', 'one', 'work'],
#   ['wise', 'decision', 'know', 'make'],
#   ['shouldve', 'invent', 'sooner', 'someone'],
#   ['good', 'price'],
#   ['good',
#    'construction',
#    'clever',
#    'first',
#    'everything',
#    'device',
#    'feel',
#    'work',
#    'trythe',
#    'engineer',
#    'certainly',
#    'way'],
#   ['quickly', 'receive', 'great', 'work'],
#   ['great', 'work'],
#   ['get', 'really', 'battery', 'fast', 'good'],
#   ['enough',
#    'case',
#    'slim',
#    'dock',
#    'clock',
#    'without',
#    'remove',
#    'also',
#    'station',
#    'alarm',
#    'fit'],
#   ['phone', 'hold', 'like', 'new', 'charge'],
#   ['lot', 'get', 'compliment'],
#   ['phone',
#    'not',
#    'definitely',
#    'allow',
#    'cell',
#    'must',
#    'usage',
#    'state',
#    'drive'],
#   ['device', 'love'],
#   ['happy', 'price', 'also'],
#   ['problem', 'voice', 'no', 'able', 'dial', 'car'],
#   ['good', 'low', 'item', 'price'],
#   ['comfortable'],
#   ['phone',
#    '2',
#    'replacement',
#    'well',
#    'come',
#    'original',
#    'battery',
#    'ago',
#    'years',
#    'work'],
#   ['reception', 'excellent'],
#   ['comfortably',
#    'charge',
#    'last',
#    'either',
#    'ear',
#    'days',
#    'loud',
#    'couple',
# ...
#    'rate',
#    'giallo',
#    'movies',
#    'film',
#    'funny',
#    'stink',
#    'zombie',
#    'supernatural',
#    'fulci'],
#   ['film', 'avoid', 'cost'],
#   ['season', 'five', 'know', 'dont', 'mess', 'happen'],
#   ['laselva',
#    'amaze',
#    'thread',
#    'together',
#    'conflict',
#    'anita',
#    'taelons',
#    'hold',
#    'performances',
#    'series',
#    'quiet',
#    'leni',
#    'parker',
#    'idealogical',
#    'consistent',
#    'two'],
#   ['dislike', 'really', 'movie'],
#   ['horror',
#    '90s',
#    'center',
#    'movies',
#    'bore',
#    'one',
#    'start',
#    'mainly',
#    'slow',
#    'atmosphere'],
#   ['way',
#    'not',
#    'really',
#    'look',
#    'cheesy',
#    'flick',
#    'like',
#    'puppet',
#    '80s',
#    'good',
#    'puppets',
#    'master'],
#   ['sinister',
#    'not',
#    'really',
#    'lame',
#    'never',
#    'explain',
#    'interest',
#    'story',
#    'puppets',
#    'origins'],
#   ['fx', 'terrible', 'movies', 'like', 'arent', 'previous', 'scenes', 'death'],
#   ['first', 'time', 'felt', 'watch', 'recommend', 'insomniacs', 'asleep'],
#   ['waste', 'time', 'dont', 'even', 'otherwise'],
#   ['create', 'suspense', 'real', 'one', 'fail'],
#   ['killer',
#    'frighten',
#    'original',
#    'dont',
#    'expect',
#    'anything',
#    'remotely',
#    'even'],
#   ['sorry', 'really', 'cant', 'recommend', 'anyone', 'but', 'im'],
#   ['boringpointless', 'movies', 'see', 'one', 'ever'],
#   ['plot',
#    'incomprehensible',
#    'relation',
#    'secondary',
#    'line',
#    'mystify',
#    'primary'],
#   ['hat'],
#   ['2',
#    'not',
#    'quite',
#    'bad',
#    'speed',
#    'bullock',
#    'since',
#    'one',
#    'sandra',
#    'but',
#    'movie',
#    'worst'],
#   ['shelve',
#    'get',
#    'garbage',
#    'not',
#    'store',
#    'real',
#    'dont',
#    'movie',
#    'even',
#    'understand'],
#   ['like', 'anyone', 'doubt', 'highly', 'trash', 'ever', 'could'],
#   ['not', 'moviemaking'],
#   ['read',
#    'wooden',
#    'book',
#    'bad',
#    'watch',
#    'around',
#    'like',
#    'act',
#    'thats',
#    'move',
#    'puppets'],
#   ['not', 'dumbest', 'youdo', 'thing', 'warn', 'rent', 'never', 'see', 'movie'],
#   ['bad', 'pretty', 'jessica', 'movie', 'agree'],
#   ['bad', 'character', 'guy', 'onedimensional', 'especially', 'good', 'even'],
#   ['totally', 'line', 'predictable', 'story'],
#   ['intelligent', 'ive', 'see', 'operas', 'movie', 'soap'],
#   ['bad', 'character', 'act', 'story'],
#   ['really', 'awful'],
#   ['not', 'watch', 'easy'],
#   ['groove', 'whatever', 'traffic', 'avoid', 'antithesis', 'good', 'human'],
#   ['subpar',
#    'film',
#    'mess',
#    'involve',
#    'crow',
#    'far',
#    'everyone',
#    'dedication',
#    'wed',
#    'else',
#    'level',
#    'bad',
#    'hand',
#    'quality',
#    'didnt',
#    'better',
#    'share'],
#   ['first', 'seem', 'slow', 'movie', 'little'],
#   ['glad',
#    'na',
#    'film',
#    'act',
#    'away',
#    'far',
#    'drift',
#    'gon',
#    'possible',
#    'earth',
#    'youre'],
#   ['small',
#    'surf',
#    'movies',
#    'deep',
#    'fail',
#    'armageddon',
#    'wave',
#    'space',
#    'one',
#    '1998',
#    'everywhere',
#    'impact',
#    'want'],
#   ['havent',
#    'end',
#    'time',
#    'drama',
#    'death',
#    'must',
#    'youve',
#    'cheap',
#    'dialogue',
#    'bore',
#    'choke',
#    'waste',
#    'vomit',
#    'worthless'],
#   ['get', 'whiny', 'bore', 'brat', 'fest', 'instead', 'babysitting', 'spoil'],
#   ['never', 'faster', 'movie', 'walk'],
#   ['get', 'jessice', 'watch', 'take', 'bore', 'lange', 'clothe'],
#   ['unfortunately',
#    'lose',
#    'script',
#    'film',
#    'virtue',
#    'work',
#    'regrettable',
#    'production'],
#   ['embarrass', 'word'],
#   ['exceptionally', 'bad'],
#   ['money', 'waste', 'intelligence', 'ones', 'insult', 'huge'],
#   ['doesnt', 'work'],
#   ['not', 'unfortunately', 'work'],
#   ['three', 'use', 'break', 'within', 'months', 'two'],
#   ['buy', 'dont'],
#   ['father', 'battery', 'die', 'v265'],
#   ['lose', 'easily', 'however', 'pad', 'come', 'ear', 'week', 'one'],
#   ['phone',
#    'call',
#    'screen',
#    'stop',
#    'come',
#    'intermittently',
#    'drop',
#    'go',
#    'black',
#    'ring',
#    'worst'],
#   ['protector', 'horrible'],
#   ['either', 'nokia', 'like', 'dont'],
#   ['bottom',
#    'not',
#    'uncomfortable',
#    'end',
#    'be3',
#    'reach',
#    'row',
#    'expect',
#    'send',
#    'key'],
#   ['phone', 'buy', 'cell', 'nokia', 'ago', 'nightmare', 'weeks'],
#   ['service',
#    'experience',
#    'long',
#    'bad',
#    'amazon',
#    'take',
#    'customer',
#    'describe',
#    'would'],
#   ['no', 'thing', 'disappoint', 'speakerphone'],
#   ['not', 'accept', 'terrible', 'car', 'cassette'],
#   ['enough',
#    'not',
#    '2',
#    'plan',
#    'use',
#    'since',
#    'product',
#    'current',
#    'cellphones',
#    'useless',
#    'charge'],
#   ['not', 'say'],
#   ['q', 'stay', 'away'],
#   ['use', 'dirty'],
#   ['service', 'unreliable', 'tmobile'],
#   ['enough', 'not', 'price', 'good'],
#   ['buy', 'neither', 'two', 'charge'],
#   ['outlet', 'ear', 'sensor', 'products', 'light', 'important', 'cover'],
#   ['not', 'work'],
#   ['reliability', 'poor'],
#   ['let',
#    'beep',
#    'take',
#    'bar',
#    'battery',
#    'know',
#    'picture',
#    'drop',
#    'die',
#    'start'],
#   ['money', 'waste', 'terrible', 'product'],
#   ['last', 'buy', 'time'],
#   ['money', 'waste'],
#   ['item', 'receive', 'counterfeit'],
#   ['far', 'purchase', 'ive', 'amazon', 'make', 'worst'],
#   ['music', 'not', '8125', 'listen', 'cingular', 'work'],
#   ['gimmick', 'lineanother', 'cheap', 'sprint', 'worthless', 'bottowm'],
#   ['volume', 'trouble'],
#   ['not', 'buy', 'warn'],
#   ['turn', 'connection', 'battery', 'break', 'device', 'open'],
#   ['discomfort', 'clip', 'cause', 'ear', 'didnt', 'go', 'top', 'want'],
#   ['website', 'trust', 'support', 'dont', 'expect', 'helpful'],
#   ['low', 'tone', 'cheap', 'quality', 'speaker', 'sound', 'make', 'ring'],
#   ['reception', 'bad'],
#   ['high', 'crap', 'quality', 'chinese', 'product'],
#   ['buy', 'product', 'dont', 'fail'],
#   ['everything', 'product', 'wrongfirst'],
#   ['contact',
#    'lose',
#    'utterly',
#    'cause',
#    'first',
#    'couple',
#    'important',
#    'confuse'],
#   ['phone', 'holder', 'terrible'],
#   ['problem', 'loop', 'easily', 'ear', 'material', 'break', 'make', 'weak'],
#   ['not', 'look', 'amazon', 'nearly', 'make', 'picture', 'good'],
#   ['stupid'],
#   ['always', 'signal', 'cut', 'sound', 'make', 'say', 'beep', 'fail'],
#   ['figure', 'couldnt'],
#   ['phone',
#    'not',
#    'totally',
#    'almost',
#    'unintelligible',
#    'wifes',
#    'great',
#    'couldnt',
#    'word',
#    'sound',
#    'but',
#    'say',
#    'ok',
#    'understand'],
#   ['phone', 'restart', 'together', 'take', 'battery', 'put', 'back'],
#   ['enough',
#    'leaf',
#    'drop',
#    'manage',
#    'back',
#    'bend',
#    'spring',
#    'break',
#    'place',
#    'metal',
#    'stress',
#    'next'],
#   ['piece', 'junk', 'saggy', 'floppy'],
#   ['problem', 'new', 'also'],
#   ['phone', 'connection', 'feet', 'loose', 'couple', 'within', 'even', 'two'],
#   ['not', 'wear', 'bluetooth', 'easier', 'make', 'im', 'keep'],
#   ['say', 'abovepretty', 'useless'],
#   ['get', 'never'],
#   ['ever', 'headphones', 'soundwise', 'pair', 'worst'],
#   ['weak', 'drain', 'snap'],
#   ['phone', 'not', '8525', 'cingular', 'att', 'charge'],
#   ['call',
#    'receive',
#    'screen',
#    'year',
#    'start',
#    'fliptop',
#    'get',
#    'however',
#    'couldnt',
#    'eventually',
#    'go',
#    'place',
#    'loose',
#    'black',
#    'wobbly'],
#   ['phone', 'pull', 'turn', 'cable', 'catch', 'seat', 'keep'],
#   ['joke', 'quite', 'low', 'volume', 'mic'],
#   ['return', 'im'],
#   ['not', 'maintain', 'connection', 'lap', 'computer'],
#   ['purchase', 'different', 'case'],
#   ['company', 'much', 'disappoint'],
#   ['charge', 'didnt'],
#   ['small', 'button'],
#   ['tinny', 'keypads', 'wrong', 'however', 'sometimes', 'reach', 'button'],
#   ['not', 'call', 'certain', 'make', 'place'],
#   ['phone',
#    'however',
#    'time',
#    'like',
#    'complain',
#    'normal',
#    'doesnt',
#    'wake',
#    'girl'],
#   ['not',
#    'charge',
#    'company',
#    'refund',
#    'restock',
#    'give',
#    'fee',
#    'still',
#    'back'],
#   ['refund', 'im', 'return', 'try'],
#   ['not', 'thing', 'plug', 'find', 'darn', 'work'],
#   ['break', 'piece', 'earbud', 'easily'],
#   ['product', 'lousy'],
#   ['phone', 'hard', 'everything', 'ability', 'but', 'fail', 'try'],
#   ['enough', 'not', 'volume'],
#   ['echo', 'problemvery', 'unsatisfactory'],
#   ['2', 'quality', 'videos', 'time', 'take', 'poor', 'could'],
#   ['money', 'dont', 'waste'],
#   ['negatively', 'first', 'review', 'product', 'go'],
#   ['enough', 'not', 'provide', 'adapter', 'current', 'charge'],
#   ['phone', 'mistake', 'much', 'assume', 'hype', 'best'],
#   ['not', 'take', 'cover', 'also', 'picture', 'lense', 'case'],
#   ['phone', 'fall', 'easily'],
#   ['people', 'not', 'talk', 'didnt', 'work', 'hear'],
#   ['really', 'message', 'tricky', 'feature', 'use', 'text'],
#   ['really', 'doesnt', 'work', 'im', 'charger', 'disappoint'],
#   ['painful', 'ear'],
#   ['blow', 'last', 'one', 'day'],
#   ['disappoint'],
#   ['flop', 'around', 'kind'],
#   ['get', 'easily', 'screen', 'touch', 'ear', 'face', 'smudge'],
#   ['phone', 'call', 'lose', 'piece', 'junk'],
#   ['not', 'item', 'match', 'picture'],
#   ['port', 'thing', 'red', 'infra', 'irda', 'disappoint'],
#   ['not', 'call', 'never', 'unit', 'work', 'answer'],
#   ['contain',
#    'not',
#    'peanuts',
#    'no',
#    'warn',
#    'menu',
#    'absolutely',
#    'allergy',
#    'waitress',
#    'clue',
#    'meals'],
#   ['bite', 'price', 'concern', 'mellow', 'mushroom'],
#   ['thai', 'ever', 'worst'],
#   ['unprofessional', 'patron', 'highly', 'rude', 'loyal'],
#   ['money', 'elsewhere', 'spend'],
#   ['far', 'bellagio', 'buffet', 'anticipate'],
#   ['drink', 'people', 'weak'],
#   ['not', 'order', 'correct'],
#   ['not', 'house', 'buy', 'like', 'also', 'feel', 'make', 'chip'],
#   ['elsewhere', 'dessert', 'dinner', 'go', 'disappoint'],
#   ['return', 'wont'],
#   ['cut',
#    'run',
#    'seriously',
#    'many',
#    'unexperienced',
#    'employees',
#    'owner',
#    'around',
#    'like',
#    'chickens',
#    'head',
#    'not',
#    'believe'],
#   ['sad'],
#   ['another',
#    'felt',
#    'talk',
#    'like',
#    'disrespect',
#    'insult',
#    'judge',
#    'human',
#    'could'],
#   ['call',
#    'cook',
#    'steak',
#    'cant',
#    'properly',
#    'steakhouse',
#    'dont',
#    'understand'],
#   ['not', 'food', 'concept', 'im', 'impress'],
#   ['puréed', 'thing', 'like', 'wasnt', 'crazy', 'dont', 'guacamole'],
#   ['really', 'experience', 'nothing', 'hope', 'better', 'postinos'],
#   ['get', 'poison', 'food', 'buffet'],
#   ['yay',
#    'no',
#    'think',
#    'something',
#    'batch',
#    'warm',
#    'bring',
#    'but',
#    'fresh',
#    'fry'],
#   ['hilarious',
#    'us',
#    'fail',
#    'remember',
#    'yummy',
#    'christmas',
#    'entire',
#    'dinner',
#    'eve',
#    'trip',
#    'biggest'],
#   ['wont', 'anytime', 'needle', 'say', 'go', 'back', 'soon'],
#   ['disgust', 'place'],
#   ['joke', 'style', 'calamari', 'ri'],
#   ['much', 'however', 'barely', 'garlic', 'edible', 'fondue'],
#   ['stomach',
#    'meal',
#    'lunch',
#    'barely',
#    'business',
#    'didnt',
#    'but',
#    'complain',
#    'could'],
#   ['bad', 'lose', 'finish', 'heart'],
#   ['forever', 'us', 'ask', 'take', 'also', 'bring', 'check'],
#   ['restaurants',
#    'itdefinitely',
#    'get',
#    'ones',
#    'dont',
#    'but',
#    'make',
#    'one',
#    'love',
#    'scene',
#    'lose',
#    'arent'],
#   ['experience', 'disappoint'],
#   ['not', 'good', 'food', 'dennys', 'say', 'par'],
#   ['service',
#    'terrible',
#    'food',
#    'mediocre',
#    'wait',
#    'place',
#    'want',
#    'downright'],
#   ['rat', 'waaaaaayyyyyyyyyy', 'say'],
#   ['wont', 'go', 'back'],
#   ['clean', 'simply', 'food', 'worth', 'wasnt', 'fairly', 'but', 'place'],
#   ['place', 'lack', 'style'],
#   ['full', 'half', 'sangria', '12', 'ridiculous', 'glass', 'wine'],
#   ['come', 'bother', 'dont'],
#   ['pull', 'dry', 'meat', 'slice', 'pretty', 'brisket', 'pork'],
#   ['build',
#    'neat',
#    'trippy',
#    'eat',
#    'bathroom',
#    'wouldnt',
#    'seem',
#    'but',
#    'pretty'],
#   ['equally', 'awful'],
#   ['not', 'go', 'hurry', 'probably', 'back'],
#   ['reservation', 'slow', 'even', 'seat'],
#   ['not', 'imagination', 'good', 'stretch'],
#   ['undercooked', 'bland', 'vegetables', 'cashew', 'cream', 'sauce'],
#   ['tasteless',
#    'water',
#    'no',
#    'heat',
#    'ranch',
#    'seem',
#    'chipolte',
#    'sause',
#    'dip',
#    'thin'],
#   ['enough', 'bite', 'not', 'really', 'flavor', 'lack', 'spicy', 'sweet'],
#   ['disappoint'],
#   ['horrible', 'place', 'way', 'overprice'],
#   ['ive',
#    'think',
#    'fare',
#    'average',
#    'maybe',
#    'but',
#    'vegetarian',
#    'twice',
#    'best'],
#   ['busy', 'wasnt', 'know'],
#   ['not',
#    'table',
#    'lot',
#    'always',
#    'time',
#    'dirty',
#    'menu',
#    'also',
#    'workers',
#    'friendly',
#    'outside',
#    'helpful'],
#   ['not',
#    'indoor',
#    'tea',
#    'garden',
#    'ambiance',
#    'like',
#    'set',
#    'douchey',
#    'feel',
#    'but',
#    'biscuits',
#    'buffet'],
#   ['con', 'service', 'spotty'],
#   ['not', 'burger', 'neither', 'hot', 'fry'],
#   ['cold', 'come', 'but', 'back'],
#   ['disappointment', 'ensue', 'come', 'food'],
#   ['disappointment', 'waiter', 'real'],
#   ['not',
#    'husband',
#    'bad',
#    'food',
#    'anything',
#    'say',
#    'apologize',
#    'rude',
#    'even'],
#   ['binge',
#    'carbs',
#    'get',
#    'reason',
#    'night',
#    'would',
#    'stomach',
#    'eat',
#    'drink',
#    'fill'],
#   ['smoke',
#    'profound',
#    'break',
#    'serve',
#    'insult',
#    'go',
#    'solidify',
#    'outside',
#    'deuchebaggery'],
#   ['part',
#    'service',
#    'think',
#    'ala',
#    'someone',
#    'may',
#    'ask',
#    'customer',
#    'dont',
#    'combo',
#    'tacos',
#    'cart',
#    'order',
#    'two'],
#   ['quite', 'blame', 'need', 'door', 'although', 'place', 'disappoint'],
#   ['disappointment', 'eat', 'couldnt', 'review', 'herewhat', 'wait', 'rave'],
#   ['taco', 'del', 'nasty', 'avoid', 'possible', 'pretty'],
#   ['not', 'hard', 'decent', 'hamburger', 'make'],
#   ['like', 'dont', 'but'],
#   ['no', 'hell', 'go', 'back'],
#   ['get',
#    'service',
#    'weve',
#    'receive',
#    'much',
#    'pizza',
#    'better',
#    'door',
#    'place',
#    'next',
#    'restaurant'],
#   ['yaall', 'wont', 'deal', 'big', 'know', 'dont', 'but', 'place', 'back'],
#   ['not',
#    'immediately',
#    'talk',
#    'shots',
#    'bar',
#    'guy',
#    'behind',
#    'say',
#    'manager',
#    'but',
#    'fireball',
#    'want'],
#   ['much', 'ambiance', 'isnt', 'better'],
#   ['unfortunately', 'us', 'disapppointment', 'set', 'entrees'],
#   ['wasnt', 'good', 'food'],
#   ['heimer', 'server', 'suck', 'correction', 'wait', 'servers'],
#   ['prettyoff', 'put', 'next', 'happen'],
#   ['really', 'bad', 'cause', 'family', 'like', 'know', 'place', 'want'],
#   ['get', 'overprice'],
#   ['mid', 'bathroom', 'vomit', 'lunch'],
#   ['minutes',
#    '35',
#    'look',
#    'no',
#    'yet',
#    'become',
#    'time',
#    'food',
#    'still',
#    'keep',
#    'soon'],
#   ['no',
#    'ever',
#    'eat',
#    'circumstances',
#    'list',
#    'return',
#    'top',
#    'place',
#    'would'],
#   ['color',
#    'brownish',
#    'obviously',
#    'tuna',
#    'wasnt',
#    'start',
#    'sashimi',
#    'fresh'],
#   ['average', 'food'],
#   ['bite',
#    'nachos',
#    'sure',
#    'movies',
#    'come',
#    'but',
#    'expect',
#    'little',
#    'would',
#    'beat',
#    'restaurant'],
#   ['bite', 'long', 'bay', 'flop', 'ha'],
#   ['problem',
#    'bigger',
#    'no',
#    'amount',
#    'subway',
#    'vegetables',
#    '1199',
#    'sandwich',
#    'charge',
#    'sub',
#    'offer',
#    'better'],
#   ['cold',
#    'ice',
#    'brushfire',
#    'mile',
#    '12',
#    'live',
#    'unwrap',
#    'literally',
#    'shrimp'],
#   ['undercooked', 'flavor', 'dry', 'seem', 'lack'],
#   ['really', 'hasnt', 'close', 'place', 'impressive'],
#   ['stay', 'mirage', 'avoid', 'place', 'would'],
#   ['meal', 'dry', 'come', 'food', 'bland', 'bean', 'refried', 'crusty'],
#   ['money', 'spend', 'time', 'else', 'place'],
#   ['table',
#    'lady',
#    'caterpillar',
#    'us',
#    'green',
#    'live',
#    'salad',
#    'find',
#    'next'],
#   ['awful', 'presentation', 'food'],
#   ['cant', 'tell', 'disappoint'],
#   ['flavor', 'think', 'food', 'lack', 'texture'],
#   ['appetite', 'instantly', 'go'],
#   ['not', 'go', 'overall', 'impress', 'back', 'would'],
#   ['whole',
#    'experience',
#    'think',
#    'well',
#    'ninja',
#    'sushi',
#    'time',
#    'go',
#    'underwhelming',
#    'next'],
#   ['enough',
#    'life',
#    'time',
#    'bring',
#    'pour',
#    'hadnt',
#    'take',
#    'draw',
#    'waste',
#    'salt',
#    'check',
#    'wind']]]

# %% [markdown]
# ### Construct feature vectors

# %%
train_comments = filtered[0] + filtered[2]
train_labels = [1]*1200 + [0]*1200
test_comments = filtered[1] + filtered[3]
test_labels = [1]*300 + [0]*300
print(len(train_comments), len(test_comments))
# Out:
# 2400 600

# %%
word_set = set()
for comment in train_comments:
    for word in comment:
        word_set.add(word)
print(len(word_set))
# Out:
# 3975

# %%
import pandas as pd

train_f = np.zeros((len(train_comments), len(word_set)))
test_f = np.zeros((len(test_comments), len(word_set)))

train_df = pd.DataFrame(train_f, columns=word_set)
print(train_df.shape)
for i, comment in enumerate(train_comments):
    for word in comment:
        train_df.iloc[i][word] += 1
train_df = train_df.astype('int32')
print(train_df.iloc[0], train_df.iloc[1])

test_df = pd.DataFrame(test_f, columns=word_set)
print(test_df.shape)
for i, comment in enumerate(test_comments):
    for word in comment:
        if word in test_df.columns:
            test_df.iloc[i][word] += 1
test_df = test_df.astype('int32')
# Out:
# (2400, 3975)
# companion      0
# crayon         0
# crisp          0
# reviewer       0
# theme          0
# whoa           0
# moz            0
# offend         0
# excelent       0
# avocado        0
# movie          1
# span           0
# beyond         0
# thorn          0
# shell          0
# closeup        0
# brief          0
# research       0
# chinese        0
# anytime        0
# speed          0
# engage         0
# sound          0
# candle         0
# piano          0
# certainly      0
# story          0
# transform      0
# hackneyed      0
# hand           0
#               ..
# luvs           0
# constantly     0
# shed           0
# mind           0
# hour           0
# role           0
# fantastic      0
# pander         0
# direct         0
# amazingrge     0
# heres          0
# luck           0
# option         0
# eiko           0
# mesquite       0
# baklava        0
# greenstreet    0
# nano           0
# fantasy        0
# snug           0
# drink          0
# clean          0
# format         0
# small          0
# capability     0
# speaker        0
# fraction       0
# soooo          0
# originality    0
# unneeded       0
# Name: 0, Length: 3975, dtype: int32 companion      0
# crayon         0
# crisp          0
# reviewer       0
# theme          0
# whoa           0
# moz            0
# offend         0
# excelent       0
# avocado        0
# movie          1
# span           0
# beyond         0
# thorn          0
# shell          0
# closeup        0
# brief          0
# research       0
# chinese        0
# anytime        0
# speed          0
# engage         0
# sound          0
# candle         0
# piano          0
# certainly      0
# story          0
# transform      0
# hackneyed      0
# hand           0
#               ..
# luvs           0
# constantly     0
# shed           0
# mind           0
# hour           0
# role           0
# fantastic      0
# pander         0
# direct         0
# amazingrge     0
# heres          0
# luck           0
# option         0
# eiko           0
# mesquite       0
# baklava        0
# greenstreet    0
# nano           0
# fantasy        0
# snug           0
# drink          0
# clean          0
# format         0
# small          0
# capability     0
# speaker        0
# fraction       0
# soooo          0
# originality    0
# unneeded       0
# Name: 1, Length: 3975, dtype: int32
# (600, 3975)

# %% [markdown]
# ### Postprocess with log norm

# %%
train_norm = np.log(train_df.values + 1)
test_norm = np.log(test_df.values + 1)
print(train_norm.shape)
# Out:
# (2400, 3975)

# %% [markdown]
# ### Logistic regression on bag-of-words model

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(random_state=0).fit(train_norm, train_labels)
# clf.predict(test_norm)
lr_score = lr.score(test_norm, test_labels)
print(lr_score)
# Out:
# 0.8316666666666667

# %%
print(lr.coef_)
lr_top_identifiers = []
for idx in np.argsort(lr.coef_)[:100]:
    lr_top_identifiers.append(test_df.columns[idx])
print(lr_top_identifiers)
# Out:
# [[ 0.09273245 -0.13037811  0.41258218 ...  0.26019976 -0.12338114
#    0.23647963]]
# [Index(['bad', 'not', 'poor', 'worst', 'terrible', 'didnt', 'awful', 'waste',
#        'suck', 'disappointment',
#        ...
#        'awesome', 'fantastic', 'best', 'amaze', 'good', 'nice', 'excellent',
#        'delicious', 'love', 'great'],
#       dtype='object', length=3975)]

# %% [markdown]
# ### Multinomial naive bayes on bag-of-words model

# %%
from sklearn.naive_bayes import MultinomialNB
mnb = MultinomialNB().fit(train_norm, train_labels)
mnb_score = mnb.score(test_norm, test_labels)
print(mnb_score)

mnb_top_identifiers = []
for idx in np.argsort(mnb.coef_)[:100]:
    mnb_top_identifiers.append(test_df.columns[idx])
print(mnb_top_identifiers)
# Out:
# 0.825
# [Index(['gore', 'z', 'badwellits', 'boob', 'québec', 'lugosi', 'reflect',
#        'stereotypically', 'carlys', 'sorry',
#        ...
#        'well', 'one', 'movie', 'love', 'work', 'but', 'phone', 'film', 'good',
#        'great'],
#       dtype='object', length=3975)]

# %% [markdown]
# ### Classification on 2-gram model

# %%
gram_set = set()
for comment in train_comments:
    for i in range(1, len(comment)):
        gram_set.add(comment[i-1] + " " + comment[i])
print(len(gram_set))
# Out:
# 11654

# %%
gram_train_f = np.zeros((len(train_comments), len(gram_set)))
gram_test_f = np.zeros((len(test_comments), len(gram_set)))

gram_train_df = pd.DataFrame(gram_train_f, columns=gram_set)
print(gram_train_df.shape)

for i, comment in enumerate(train_comments):
    for j in range(1, len(comment)):
        gram = comment[j-1] + " " + comment[j]
        gram_train_df.iloc[i][gram] += 1
gram_train_df = gram_train_df.astype('int32')
print(gram_train_df.iloc[0], gram_train_df.iloc[1])

gram_test_df = pd.DataFrame(gram_test_f, columns=gram_set)
print(gram_test_df.shape)
for i, comment in enumerate(test_comments):
    for j in range(len(comment)):
        gram = comment[j-1] + " " + comment[j]
        if gram in gram_test_df.columns:
            gram_test_df.iloc[i][gram] += 1
gram_test_df = gram_test_df.astype('int32')
# Out:
# (2400, 11654)
# part near           0
# drain 50            0
# shoot use           0
# ago like            0
# think heist         0
# totally burger      0
# reduction wine      0
# actingwise wasnt    0
# william john        0
# great value         0
# price anyways       0
# food meatloaf       0
# half lose           0
# youll thin          0
# like cover          0
# stagy attention     0
# paradise work       0
# make little         0
# make grime          0
# spacek great        0
# horrible pull       0
# assistant bakery    0
# like live           0
# find product        0
# bar cant            0
# food us             0
# leave hungry        0
# doesnt asia         0
# whine hour          0
# use documentary     0
#                    ..
# every worth         0
# wall watch          0
# wire long           0
# minute important    0
# camera balance      0
# rochonwas but       0
# phone razr          0
# time monster        0
# may go              0
# color costume       0
# eye black           0
# curry dish          0
# care interest       0
# even car            0
# dont movie          0
# way exchange        0
# character care      0
# havent go           0
# new walkman         0
# get plug            0
# worry actors        0
# 810 score           0
# doubt fry           0
# time ear            0
# check back          0
# ear fit             0
# cant beat           0
# much sushi          0
# interest town       0
# pumpkin moms        0
# Name: 0, Length: 11654, dtype: int32 part near           0
# drain 50            0
# shoot use           0
# ago like            0
# think heist         0
# totally burger      0
# reduction wine      0
# actingwise wasnt    0
# william john        0
# great value         0
# price anyways       0
# food meatloaf       0
# half lose           0
# youll thin          0
# like cover          0
# stagy attention     0
# paradise work       0
# make little         0
# make grime          0
# spacek great        0
# horrible pull       0
# assistant bakery    0
# like live           0
# find product        0
# bar cant            0
# food us             0
# leave hungry        0
# doesnt asia         0
# whine hour          0
# use documentary     0
#                    ..
# every worth         0
# wall watch          0
# wire long           0
# minute important    0
# camera balance      0
# rochonwas but       0
# phone razr          0
# time monster        0
# may go              0
# color costume       0
# eye black           0
# curry dish          0
# care interest       0
# even car            0
# dont movie          0
# way exchange        0
# character care      0
# havent go           0
# new walkman         0
# get plug            0
# worry actors        0
# 810 score           0
# doubt fry           0
# time ear            0
# check back          0
# ear fit             0
# cant beat           0
# much sushi          0
# interest town       0
# pumpkin moms        0
# Name: 1, Length: 11654, dtype: int32
# (600, 11654)

# %%
gram_train_norm = np.log(gram_train_df.values + 1)
gram_test_norm = np.log(gram_test_df.values + 1)
print(gram_train_norm.shape)

gram_lr = LogisticRegression(random_state=0).fit(gram_train_norm, train_labels)
gram_lr_score = gram_lr.score(gram_test_norm, test_labels)
print(gram_lr_score)

gram_lr_top_identifiers = []
for idx in np.argsort(gram_lr.coef_)[:100]:
    gram_lr_top_identifiers.append(gram_test_df.columns[idx])
print(gram_lr_top_identifiers)

gram_mnb = MultinomialNB().fit(gram_train_norm, train_labels)
gram_mnb_score = gram_mnb.score(gram_test_norm, test_labels)
print(gram_mnb_score)

gram_mnb_top_identifiers = []
for idx in np.argsort(gram_mnb.coef_)[:100]:
    gram_mnb_top_identifiers.append(gram_test_df.columns[idx])
print(gram_mnb_top_identifiers)
# Out:
# (2400, 11654)
# 0.605
# [Index(['waste time', 'not good', 'phone not', 'ever worst', 'dont go',
#        'service bad', 'but place', 'not recommend', 'not back', 'minutes get',
#        ...
#        'place love', 'waitress friendly', 'ever best', 'price great',
#        'give 10', 'recommend highly', 'phone great', 'great film',
#        'great work', 'great food'],
#       dtype='object', length=11654)]
# 0.6083333333333333
# [Index(['part near', 'turn definitely', 'would probably', 'time warmer',
#        'publicly figure', 'obviously customer', 'place anyone', 'help forth',
#        'unfortunately high', 'steep worth',
#        ...
#        'give 10', 'price great', 'dont but', 'recommend highly', 'ever best',
#        'but work', 'phone great', 'great work', 'great food', 'great film'],
#       dtype='object', length=11654)]

# %% [markdown]
# ### Classification with PCA

# %%
from sklearn.decomposition import PCA

def reconstruct(org, n):
    u, s, vt = np.linalg.svd(org, full_matrices=False)
    return np.dot(np.dot(u[:, :n], np.diag(s)[:n, :n]), vt[:n, :])
    
# u, s, vt = np.linalg.svd(train_norm, full_matrices=False)
# print(np.dot(np.dot(u, np.diag(s)), vt))
# print(train_norm)
# print(PCA(n_components=100).fit_transform(train_norm))

train_r = []
test_r = []

train_r.extend((reconstruct(train_norm, 10), 
               reconstruct(train_norm, 50), 
               reconstruct(train_norm, 100), 
               reconstruct(gram_train_norm, 10),
               reconstruct(gram_train_norm, 50), 
               reconstruct(gram_train_norm, 100)))
test_r.extend((reconstruct(test_norm, 10), 
              reconstruct(test_norm, 50), 
              reconstruct(test_norm, 100), 
              reconstruct(gram_test_norm, 10),
              reconstruct(gram_test_norm, 50), 
              reconstruct(gram_test_norm, 100)))

# u, s, vt = np.linalg.svd(train_norm)
# train_r10 = np.dot(np.dot(u[:, :10], np.diag(s)[:10, :10]), vt[:10,:])
# train_r50 = np.dot(np.dot(u[:, :50], np.diag(s)[:50, :50]), vt[:50,:])
# train_r100 = np.dot(np.dot(u[:, :100], np.diag(s)[:100, :100]), vt[:100,:])

# gram_u, gram_s, gram_vt = np.linalg.svd(gram_train_norm)
# gram_train_r10 = np.dot(np.dot(gram_u[:, :10], np.diag(gram_s)[:10, :10]), gram_vt[:10,:])
# gram_train_r50 = np.dot(np.dot(gram_u[:, :50], np.diag(gram_s)[:50, :50]), gram_vt[:50,:])
# gram_train_r100 = np.dot(np.dot(gram_u[:, :100], np.diag(gram_s)[:100, :100]), gram_vt[:100,:])

# %%
def classify(model, train_x, train_y, test_x, test_y, test_df):
    if model == "lr":
        print("lr")
        clf = LogisticRegression(random_state=0).fit(train_x, train_y)
    if model == "mnb":
        print("mnb")
        clf = MultinomialNB().fit(train_x, train_y)
    score = clf.score(test_x, test_y)
    print(score)

    top_identifiers = []
    for idx in np.argsort(clf.coef_)[:100]:
        top_identifiers.append(test_df.columns[idx])
    print(top_identifiers)

test_dfs = [test_df, gram_test_df]
for i in range(len(train_r)):
    if i < 3:
        a = 0
    else:
        a = 1
    classify("lr", train_r[i], train_labels, test_r[i], test_labels, test_dfs[a])
    classify("mnb", train_r[i]+1, train_labels, test_r[i]+1, test_labels, test_dfs[a])
# Out:
# lr
# 0.6266666666666667
# [Index(['not', 'time', 'go', 'but', 'back', 'dont', 'would', 'get', 'bad',
#        'even',
#        ...
#        'quality', 'product', 'really', 'well', 'price', 'food', 'film', 'work',
#        'good', 'great'],
#       dtype='object', length=3975)]
# mnb
# 0.6066666666666667
# [Index(['communications', 'communicate', 'holster', 'selfdiscovery', 'voyage',
#        'essentially', 'items', 'distract', 'photo', 'ad',
#        ...
#        'make', 'food', 'one', 'movie', 'but', 'phone', 'film', 'work', 'good',
#        'great'],
#       dtype='object', length=3975)]
# lr
# 0.685
# [Index(['bad', 'not', 'dont', 'no', 'would', 'much', 'waste', 'ever', 'minutes',
#        'disappoint',
#        ...
#        'product', 'excellent', 'well', 'recommend', 'best', 'good', 'nice',
#        'price', 'love', 'great'],
#       dtype='object', length=3975)]
# mnb
# 0.665
# [Index(['reccommend', 'uneasy', 'veal', 'girlfriends', 'badwellits', 'edible',
#        'dialogs', 'shallow', 'insincere', 'victor',
#        ...
#        'well', 'one', 'movie', 'love', 'work', 'but', 'phone', 'film', 'good',
#        'great'],
#       dtype='object', length=3975)]
# lr
# 0.7133333333333334
# [Index(['bad', 'not', 'waste', 'terrible', 'minutes', 'no', 'didnt', 'eat',
#        'never', 'dont',
#        ...
#        'recommend', 'price', 'play', 'amaze', 'best', 'good', 'nice',
#        'excellent', 'love', 'great'],
#       dtype='object', length=3975)]
# mnb
# 0.695
# [Index(['money', 'hackneyed', 'personalities', 'reccommend', 'uneasy', 'edible',
#        'veal', 'girlfriends', 'badwellits', 'acknowledge',
#        ...
#        'well', 'one', 'movie', 'love', 'work', 'but', 'phone', 'film', 'good',
#        'great'],
#       dtype='object', length=3975)]
# lr
# 0.49333333333333335
# [Index(['scenes movie', 'reason no', 'look bad', 'whatsoever kind',
#        'act scenes', 'slowmotion but', 'kind throw', 'vehicles slowmotion',
#        'throughout make', 'movie back',
#        ...
#        'care wouldbe', 'aerial master', 'least care', 'imagination might',
#        'fifties least', 'might director', 'sense worldweariness',
#        'significant ought', 'director great', 'great film'],
#       dtype='object', length=11654)]
# mnb
# 0.49333333333333335
# [Index(['part near', 'typical food', 'definitely fresh', 'act coach',
#        'sympathetic make', 'mediocre food', 'but cost', 'like disaster',
#        'chip count', 'dialogue sappiest',
#        ...
#        'worldweariness significant', 'thrill fifties', 'existential actors',
#        'one undertone', 'master thrill', 'deeply sense', 'might director',
#        'character deeply', 'director great', 'great film'],
#       dtype='object', length=11654)]
# lr
# 0.535
# [Index(['waste time', 'phone not', 'but place', 'but movie', 'money waste',
#        'go back', 'first time', 'time dont', 'not waste', 'time come',
#        ...
#        '1928 filmsomething', 'but 1928', 'yet mickey', 'music effect',
#        'sound dont', 'make one', 'effect sound', 'see one', 'director great',
#        'great film'],
#       dtype='object', length=11654)]
# mnb
# 0.5366666666666666
# [Index(['reason no', 'twist reason', 'occur plot', 'change real',
#        'script personalities', 'call character', 'no call', 'things happen',
#        'real things', 'plot twist',
#        ...
#        'fifties least', 'might director', 'make one', 'phone not',
#        'director great', 'dont but', 'see one', 'go back', 'great film',
#        'but work'],
#       dtype='object', length=11654)]
# lr
# 0.5283333333333333
# [Index(['waste time', 'but place', 'phone not', 'enough not', 'money waste',
#        'but movie', 'go back', 'first time', 'place would', 'not get',
#        ...
#        'sound dont', 'but try', 'ive one', 'effect sound', 'eat great',
#        'make one', 'think great', 'see one', 'great film', 'great food'],
#       dtype='object', length=11654)]
# mnb
# 0.5266666666666666
# [Index(['dont place', 'ill dont', 'waste number', 'time want', 'bad review',
#        'leave ill', 'like bland', 'place bad', 'reason leave', 'want reason',
#        ...
#        'ive one', 'but try', 'dont but', 'see one', 'work good', 'go back',
#        'phone get', 'but work', 'great food', 'great film'],
#       dtype='object', length=11654)]
